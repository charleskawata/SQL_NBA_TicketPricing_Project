# %%
from sqlalchemy import create_engine

# %%
# %load_ext sql

# %%
https://github.com/charleskawata/SQL_NBA_TicketPricing_Project

# %% [markdown]
# # Part 1 Exploratory Queries

# %% [markdown]
# Exploratory Query 1: list each team and their average attendance per game per season over the last 6 years (of the data that is in the set 2010-2015) to get a more relavent picture of teams average attendance

# %%
# %%sql
# SELECT
#     season,
#     team,
#     homeAVGAttendancePerGame,
#     REPEAT('*',(homeAVGAttendancePerGame/100) - 100) AS yearlyAttendanceGraph
# FROM nba_annual_attendance
# WHERE season IN (2010, 2011, 2012, 2013, 2014, 2015)
# ORDER BY team, season;
# Out:
#  * mysql://admin:***@lmu-dev-01.cenozo6j3rls.us-east-1.rds.amazonaws.com/nba
# 180 rows affected.
# [(2010, 'Atlanta Hawks', 15648, '********************************************************'),
#  (2011, 'Atlanta Hawks', 15199, '****************************************************'),
#  (2012, 'Atlanta Hawks', 15125, '***************************************************'),
#  (2013, 'Atlanta Hawks', 14339, '*******************************************'),
#  (2014, 'Atlanta Hawks', 17412, '**************************************************************************'),
#  (2015, 'Atlanta Hawks', 16832, '********************************************************************'),
#  (2010, 'Boston Celtics', 18624, '**************************************************************************************'),
#  (2011, 'Boston Celtics', 18624, '**************************************************************************************'),
#  (2012, 'Boston Celtics', 18624, '**************************************************************************************'),
#  (2013, 'Boston Celtics', 18107, '*********************************************************************************'),
#  (2014, 'Boston Celtics', 17593, '****************************************************************************'),
#  (2015, 'Boston Celtics', 18270, '***********************************************************************************'),
#  (2010, 'Brooklyn Nets', 14179, '******************************************'),
#  (2011, 'Brooklyn Nets', 13961, '****************************************'),
#  (2012, 'Brooklyn Nets', 17187, '************************************************************************'),
#  (2013, 'Brooklyn Nets', 17251, '*************************************************************************'),
#  (2014, 'Brooklyn Nets', 17037, '**********************************************************************'),
#  (2015, 'Brooklyn Nets', 15125, '***************************************************'),
#  (2010, 'Charlotte Hornets', 15846, '**********************************************************'),
#  (2011, 'Charlotte Hornets', 14757, '************************************************'),
#  (2012, 'Charlotte Hornets', 15324, '*****************************************************'),
#  (2013, 'Charlotte Hornets', 15518, '*******************************************************'),
#  (2014, 'Charlotte Hornets', 17192, '************************************************************************'),
#  (2015, 'Charlotte Hornets', 17485, '***************************************************************************'),
#  (2010, 'Chicago Bulls', 21791, '**********************************************************************************************************************'),
#  (2011, 'Chicago Bulls', 22161, '**************************************************************************************************************************'),
#  (2012, 'Chicago Bulls', 21876, '***********************************************************************************************************************'),
#  (2013, 'Chicago Bulls', 21716, '*********************************************************************************************************************'),
#  (2014, 'Chicago Bulls', 21343, '*****************************************************************************************************************'),
#  (2015, 'Chicago Bulls', 21820, '**********************************************************************************************************************'),
#  (2010, 'Cleveland Cavaliers', 20112, '*****************************************************************************************************'),
#  (2011, 'Cleveland Cavaliers', 15926, '***********************************************************'),
#  (2012, 'Cleveland Cavaliers', 16192, '**************************************************************'),
#  (2013, 'Cleveland Cavaliers', 17329, '*************************************************************************'),
#  (2014, 'Cleveland Cavaliers', 20562, '**********************************************************************************************************'),
#  (2015, 'Cleveland Cavaliers', 20562, '**********************************************************************************************************'),
#  (2010, 'Dallas Mavericks', 20101, '*****************************************************************************************************'),
#  (2011, 'Dallas Mavericks', 20334, '*******************************************************************************************************'),
#  (2012, 'Dallas Mavericks', 20036, '****************************************************************************************************'),
#  (2013, 'Dallas Mavericks', 19950, '****************************************************************************************************'),
#  (2014, 'Dallas Mavericks', 20187, '******************************************************************************************************'),
#  (2015, 'Dallas Mavericks', 20143, '*****************************************************************************************************'),
#  (2010, 'Denver Nuggets', 16901, '*********************************************************************'),
#  (2011, 'Denver Nuggets', 17029, '**********************************************************************'),
#  (2012, 'Denver Nuggets', 17819, '******************************************************************************'),
#  (2013, 'Denver Nuggets', 16899, '*********************************************************************'),
#  (2014, 'Denver Nuggets', 14700, '***********************************************'),
#  (2015, 'Denver Nuggets', 14095, '*****************************************'),
#  (2010, 'Detroit Pistons', 16660, '*******************************************************************'),
#  (2011, 'Detroit Pistons', 14413, '********************************************'),
#  (2012, 'Detroit Pistons', 14782, '************************************************'),
#  (2013, 'Detroit Pistons', 15005, '**************************************************'),
#  (2014, 'Detroit Pistons', 15266, '*****************************************************'),
#  (2015, 'Detroit Pistons', 16515, '*****************************************************************'),
#  (2010, 'Golden State Warriors', 18692, '***************************************************************************************'),
#  (2011, 'Golden State Warriors', 18857, '*****************************************************************************************'),
#  (2012, 'Golden State Warriors', 19373, '**********************************************************************************************'),
#  (2013, 'Golden State Warriors', 19596, '************************************************************************************************'),
#  (2014, 'Golden State Warriors', 19596, '************************************************************************************************'),
#  (2015, 'Golden State Warriors', 19596, '************************************************************************************************'),
#  (2010, 'Houston Rockets', 16191, '**************************************************************'),
#  (2011, 'Houston Rockets', 15363, '******************************************************'),
#  (2012, 'Houston Rockets', 16672, '*******************************************************************'),
#  (2013, 'Houston Rockets', 18123, '*********************************************************************************'),
#  (2014, 'Houston Rockets', 18229, '**********************************************************************************'),
#  (2015, 'Houston Rockets', 17981, '********************************************************************************'),
#  (2010, 'Indiana Pacers', 13538, '***********************************'),
#  (2011, 'Indiana Pacers', 14168, '******************************************'),
#  (2012, 'Indiana Pacers', 15269, '*****************************************************'),
#  (2013, 'Indiana Pacers', 17501, '***************************************************************************'),
#  (2014, 'Indiana Pacers', 16864, '*********************************************************************'),
#  (2015, 'Indiana Pacers', 16847, '********************************************************************'),
#  (2010, 'LA Clippers', 17742, '*****************************************************************************'),
#  (2011, 'LA Clippers', 19219, '********************************************************************************************'),
#  (2012, 'LA Clippers', 19226, '********************************************************************************************'),
#  (2013, 'LA Clippers', 19212, '********************************************************************************************'),
#  (2014, 'LA Clippers', 19168, '********************************************************************************************'),
#  (2015, 'LA Clippers', 19192, '********************************************************************************************'),
#  (2010, 'Los Angeles Lakers', 18997, '******************************************************************************************'),
#  (2011, 'Los Angeles Lakers', 18997, '******************************************************************************************'),
#  (2012, 'Los Angeles Lakers', 18997, '******************************************************************************************'),
#  (2013, 'Los Angeles Lakers', 18828, '****************************************************************************************'),
#  (2014, 'Los Angeles Lakers', 18737, '***************************************************************************************'),
#  (2015, 'Los Angeles Lakers', 18997, '******************************************************************************************'),
#  (2010, 'Memphis Grizzlies', 14650, '***********************************************'),
#  (2011, 'Memphis Grizzlies', 15704, '*********************************************************'),
#  (2012, 'Memphis Grizzlies', 16624, '******************************************************************'),
#  (2013, 'Memphis Grizzlies', 16718, '*******************************************************************'),
#  (2014, 'Memphis Grizzlies', 17329, '*************************************************************************'),
#  (2015, 'Memphis Grizzlies', 16697, '*******************************************************************'),
#  (2010, 'Miami Heat', 19778, '**************************************************************************************************'),
#  (2011, 'Miami Heat', 19935, '***************************************************************************************************'),
#  (2012, 'Miami Heat', 19982, '****************************************************************************************************'),
#  (2013, 'Miami Heat', 19781, '**************************************************************************************************'),
#  (2014, 'Miami Heat', 19712, '*************************************************************************************************'),
#  (2015, 'Miami Heat', 19740, '*************************************************************************************************'),
#  (2010, 'Milwaukee Bucks', 15412, '******************************************************'),
#  (2011, 'Milwaukee Bucks', 14718, '***********************************************'),
#  (2012, 'Milwaukee Bucks', 15035, '**************************************************'),
#  (2013, 'Milwaukee Bucks', 13487, '***********************************'),
#  (2014, 'Milwaukee Bucks', 14907, '*************************************************'),
#  (2015, 'Milwaukee Bucks', 15166, '****************************************************'),
#  (2010, 'Minnesota Timberwolves', 15242, '****************************************************'),
#  (2011, 'Minnesota Timberwolves', 17490, '***************************************************************************'),
#  (2012, 'Minnesota Timberwolves', 16340, '***************************************************************'),
#  (2013, 'Minnesota Timberwolves', 14564, '**********************************************'),
#  (2014, 'Minnesota Timberwolves', 14528, '*********************************************'),
#  (2015, 'Minnesota Timberwolves', 14175, '******************************************'),
#  (2010, 'New Orleans Pelicans', 14709, '***********************************************'),
#  (2011, 'New Orleans Pelicans', 15109, '***************************************************'),
#  (2012, 'New Orleans Pelicans', 13803, '**************************************'),
#  (2013, 'New Orleans Pelicans', 16390, '****************************************************************'),
#  (2014, 'New Orleans Pelicans', 16677, '*******************************************************************'),
#  (2015, 'New Orleans Pelicans', 16793, '********************************************************************'),
#  (2010, 'New York Knicks', 19728, '*************************************************************************************************'),
#  (2011, 'New York Knicks', 19763, '**************************************************************************************************'),
#  (2012, 'New York Knicks', 19033, '******************************************************************************************'),
#  (2013, 'New York Knicks', 19812, '**************************************************************************************************'),
#  (2014, 'New York Knicks', 19812, '**************************************************************************************************'),
#  (2015, 'New York Knicks', 19812, '**************************************************************************************************'),
#  (2010, 'Oklahoma City Thunder', 18148, '*********************************************************************************'),
#  (2011, 'Oklahoma City Thunder', 18203, '**********************************************************************************'),
#  (2012, 'Oklahoma City Thunder', 18203, '**********************************************************************************'),
#  (2013, 'Oklahoma City Thunder', 18203, '**********************************************************************************'),
#  (2014, 'Oklahoma City Thunder', 18203, '**********************************************************************************'),
#  (2015, 'Oklahoma City Thunder', 18203, '**********************************************************************************'),
#  (2010, 'Orlando Magic', 18972, '******************************************************************************************'),
#  (2011, 'Orlando Magic', 18896, '*****************************************************************************************'),
#  (2012, 'Orlando Magic', 17595, '****************************************************************************'),
#  (2013, 'Orlando Magic', 16245, '**************************************************************'),
#  (2014, 'Orlando Magic', 16785, '********************************************************************'),
#  (2015, 'Orlando Magic', 17543, '***************************************************************************'),
#  (2010, 'Philadelphia 76ers', 14751, '************************************************'),
#  (2011, 'Philadelphia 76ers', 17502, '***************************************************************************'),
#  (2012, 'Philadelphia 76ers', 16717, '*******************************************************************'),
#  (2013, 'Philadelphia 76ers', 13869, '***************************************'),
#  (2014, 'Philadelphia 76ers', 13940, '***************************************'),
#  (2015, 'Philadelphia 76ers', 14881, '*************************************************'),
#  (2010, 'Phoenix Suns', 17567, '****************************************************************************'),
#  (2011, 'Phoenix Suns', 15597, '********************************************************'),
#  (2012, 'Phoenix Suns', 15436, '******************************************************'),
#  (2013, 'Phoenix Suns', 15871, '***********************************************************'),
#  (2014, 'Phoenix Suns', 16923, '*********************************************************************'),
#  (2015, 'Phoenix Suns', 17107, '***********************************************************************'),
#  (2010, 'Portland Trail Blazers', 20510, '*********************************************************************************************************'),
#  (2011, 'Portland Trail Blazers', 20496, '*********************************************************************************************************'),
#  (2012, 'Portland Trail Blazers', 19829, '**************************************************************************************************'),
#  (2013, 'Portland Trail Blazers', 19746, '*************************************************************************************************'),
#  (2014, 'Portland Trail Blazers', 19554, '************************************************************************************************'),
#  (2015, 'Portland Trail Blazers', 19367, '**********************************************************************************************'),
#  (2010, 'Sacramento Kings', 13890, '***************************************'),
#  (2011, 'Sacramento Kings', 14508, '*********************************************'),
#  (2012, 'Sacramento Kings', 13749, '*************************************'),
#  (2013, 'Sacramento Kings', 16291, '***************************************************************'),
#  (2014, 'Sacramento Kings', 16586, '******************************************************************'),
#  (2015, 'Sacramento Kings', 17256, '*************************************************************************'),
#  (2010, 'San Antonio Spurs', 18314, '***********************************************************************************'),
#  (2011, 'San Antonio Spurs', 18396, '************************************************************************************'),
#  (2012, 'San Antonio Spurs', 18431, '************************************************************************************'),
#  (2013, 'San Antonio Spurs', 18415, '************************************************************************************'),
#  (2014, 'San Antonio Spurs', 18606, '**************************************************************************************'),
#  (2015, 'San Antonio Spurs', 18449, '************************************************************************************'),
#  (2010, 'Toronto Raptors', 16566, '******************************************************************'),
#  (2011, 'Toronto Raptors', 16835, '********************************************************************'),
#  (2012, 'Toronto Raptors', 18144, '*********************************************************************************'),
#  (2013, 'Toronto Raptors', 18252, '***********************************************************************************'),
#  (2014, 'Toronto Raptors', 19751, '**************************************************************************************************'),
#  (2015, 'Toronto Raptors', 19825, '**************************************************************************************************'),
#  (2010, 'Utah Jazz', 19511, '***********************************************************************************************'),
#  (2011, 'Utah Jazz', 19306, '*********************************************************************************************'),
#  (2012, 'Utah Jazz', 18680, '***************************************************************************************'),
#  (2013, 'Utah Jazz', 18175, '**********************************************************************************'),
#  (2014, 'Utah Jazz', 18830, '****************************************************************************************'),
#  (2015, 'Utah Jazz', 19304, '*********************************************************************************************'),
#  (2010, 'Washington Wizards', 16791, '********************************************************************'),
#  (2011, 'Washington Wizards', 16728, '*******************************************************************'),
#  (2012, 'Washington Wizards', 16343, '***************************************************************'),
#  (2013, 'Washington Wizards', 17026, '**********************************************************************'),
#  (2014, 'Washington Wizards', 18238, '**********************************************************************************'),
#  (2015, 'Washington Wizards', 17693, '*****************************************************************************')]

# %% [markdown]
# This query shows how different the league was back in the earls 2010s because some of the teams with the highest average attendance per game during the 2010-2015 seasons are not as good anymore and some of the best teams currently are at the bottom of the list in terms of average attendance per game per season.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Exploratory Query 2: list how the average cost of each teams tickets in the 2019-2020 season compares to the average across the entire league and mark whether they are under pried or over priced based on this comparison

# %%
# %%sql
# SELECT
#     teamName,
#     averageTicketCost,
#     (SELECT
#         AVG(averageTicketCost)
#     FROM nba_team_financials ntf2
#     ) AS averageAcrossAllTeams,
#     CASE
#         WHEN averageTicketCost >
#             (SELECT
#                 AVG(averageTicketCost)
#             FROM nba_team_financials ntf2) THEN 'Over Priced'
#         ELSE 'Under Priced'
#     END AS ticketPricing
# FROM nba_team_financials ntf
# GROUP BY teamName;
# Out:
#  * mysql://admin:***@lmu-dev-01.cenozo6j3rls.us-east-1.rds.amazonaws.com/nba
# 30 rows affected.
# [('Chicago Bulls', 133, Decimal('153.3000'), 'Under Priced'),
#  ('Cleveland Cavaliers', 72, Decimal('153.3000'), 'Under Priced'),
#  ('Dallas Mavericks', 110, Decimal('153.3000'), 'Under Priced'),
#  ('Toronto Raptors', 179, Decimal('153.3000'), 'Over Priced'),
#  ('New York Knicks', 261, Decimal('153.3000'), 'Over Priced'),
#  ('Miami Heat', 150, Decimal('153.3000'), 'Under Priced'),
#  ('Golden State Warriors', 458, Decimal('153.3000'), 'Over Priced'),
#  ('Portland Trail Blazers', 103, Decimal('153.3000'), 'Under Priced'),
#  ('Utah Jazz', 117, Decimal('153.3000'), 'Under Priced'),
#  ('LA Clippers', 267, Decimal('153.3000'), 'Over Priced'),
#  ('Los Angeles Lakers', 473, Decimal('153.3000'), 'Over Priced'),
#  ('San Antonio Spurs', 177, Decimal('153.3000'), 'Over Priced'),
#  ('Boston Celtics', 154, Decimal('153.3000'), 'Over Priced'),
#  ('Oklahoma City Thunder', 137, Decimal('153.3000'), 'Under Priced'),
#  ('Houston Rockets', 189, Decimal('153.3000'), 'Over Priced'),
#  ('Washington Wizards', 92, Decimal('153.3000'), 'Under Priced'),
#  ('Orlando Magic', 87, Decimal('153.3000'), 'Under Priced'),
#  ('Charlotte Hornets', 64, Decimal('153.3000'), 'Under Priced'),
#  ('Sacramento Kings', 107, Decimal('153.3000'), 'Under Priced'),
#  ('Phoenix Suns', 85, Decimal('153.3000'), 'Under Priced'),
#  ('Indiana Pacers', 94, Decimal('153.3000'), 'Under Priced'),
#  ('Atlanta Hawks', 107, Decimal('153.3000'), 'Under Priced'),
#  ('New Orleans Pelicans', 105, Decimal('153.3000'), 'Under Priced'),
#  ('Memphis Grizzlies', 73, Decimal('153.3000'), 'Under Priced'),
#  ('Detroit Pistons', 69, Decimal('153.3000'), 'Under Priced'),
#  ('Milwaukee Bucks', 132, Decimal('153.3000'), 'Under Priced'),
#  ('Brooklyn Nets', 242, Decimal('153.3000'), 'Over Priced'),
#  ('Philadelphia 76ers', 150, Decimal('153.3000'), 'Under Priced'),
#  ('Minnesota Timberwolves', 58, Decimal('153.3000'), 'Under Priced'),
#  ('Denver Nuggets', 154, Decimal('153.3000'), 'Over Priced')]

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Explanatory Query 3: Categorize NBA teams based on the number of championships they have, playoff winning percentage, and playoff appearances in the modern era (since 1980)

# %%
# %%sql
# SELECT
#     teamName,
#     championshipsSince1980,
#     playoffApperanceSince1980,
#     playoffWinsSince1980,
#     playoffLossesSince1980,
#     (playoffWinsSince1980)/(playoffWinsSince1980 +playoffLossesSince1980) AS winningPercentage,
#     CASE
#         WHEN championshipsSince1980 >= 3 THEN 'Historically Succesful Franchise'
#         WHEN championshipsSince1980 IN (1,2) OR (playoffApperanceSince1980 > 25 AND (playoffWinsSince1980)/(playoffWinsSince1980 +playoffLossesSince1980) > .45) THEN 'Moderately Succesful Franchise'
#         ELSE 'Other (New Franchise, Little Playoff Success, Recent Playoff Success)'
#     END AS FranchiseEvaluation
# FROM nba_playoff_history
# ORDER BY winningPercentage;
# Out:
#  * mysql://admin:***@lmu-dev-01.cenozo6j3rls.us-east-1.rds.amazonaws.com/nba
# 30 rows affected.
# [('Minnesota Timberwolves', 0, 9, 18, 34, Decimal('0.3462'), 'Other (New Franchise, Little Playoff Success, Recent Playoff Success)'),
#  ('Charlotte Hornets', 0, 10, 23, 40, Decimal('0.3651'), 'Other (New Franchise, Little Playoff Success, Recent Playoff Success)'),
#  ('Memphis Grizzlies', 0, 10, 29, 46, Decimal('0.3867'), 'Other (New Franchise, Little Playoff Success, Recent Playoff Success)'),
#  ('Washington Wizards', 0, 15, 38, 59, Decimal('0.3918'), 'Other (New Franchise, Little Playoff Success, Recent Playoff Success)'),
#  ('Denver Nuggets', 0, 23, 68, 105, Decimal('0.3931'), 'Other (New Franchise, Little Playoff Success, Recent Playoff Success)'),
#  ('Portland Trail Blazers', 0, 32, 90, 138, Decimal('0.3947'), 'Other (New Franchise, Little Playoff Success, Recent Playoff Success)'),
#  ('Atlanta Hawks', 0, 25, 76, 116, Decimal('0.3958'), 'Other (New Franchise, Little Playoff Success, Recent Playoff Success)'),
#  ('New Orleans Pelicans', 0, 7, 20, 29, Decimal('0.4082'), 'Other (New Franchise, Little Playoff Success, Recent Playoff Success)'),
#  ('Brooklyn Nets', 0, 20, 63, 86, Decimal('0.4228'), 'Other (New Franchise, Little Playoff Success, Recent Playoff Success)'),
#  ('Milwaukee Bucks', 0, 24, 81, 109, Decimal('0.4263'), 'Other (New Franchise, Little Playoff Success, Recent Playoff Success)'),
#  ('LA Clippers', 0, 12, 44, 57, Decimal('0.4356'), 'Other (New Franchise, Little Playoff Success, Recent Playoff Success)'),
#  ('Orlando Magic', 0, 16, 59, 74, Decimal('0.4436'), 'Other (New Franchise, Little Playoff Success, Recent Playoff Success)'),
#  ('Sacramento Kings', 0, 12, 42, 52, Decimal('0.4468'), 'Other (New Franchise, Little Playoff Success, Recent Playoff Success)'),
#  ('Dallas Mavericks', 1, 22, 93, 109, Decimal('0.4604'), 'Moderately Succesful Franchise'),
#  ('Utah Jazz', 0, 29, 127, 148, Decimal('0.4618'), 'Moderately Succesful Franchise'),
#  ('Toronto Raptors', 1, 12, 55, 62, Decimal('0.4701'), 'Moderately Succesful Franchise'),
#  ('Indiana Pacers', 0, 27, 115, 126, Decimal('0.4772'), 'Moderately Succesful Franchise'),
#  ('New York Knicks', 0, 21, 97, 106, Decimal('0.4778'), 'Other (New Franchise, Little Playoff Success, Recent Playoff Success)'),
#  ('Oklahoma City Thunder', 0, 27, 126, 136, Decimal('0.4809'), 'Moderately Succesful Franchise'),
#  ('Phoenix Suns', 0, 24, 108, 115, Decimal('0.4843'), 'Other (New Franchise, Little Playoff Success, Recent Playoff Success)'),
#  ('Philadelphia 76ers', 1, 23, 112, 113, Decimal('0.4978'), 'Moderately Succesful Franchise'),
#  ('Houston Rockets', 2, 29, 145, 142, Decimal('0.5052'), 'Moderately Succesful Franchise'),
#  ('Boston Celtics', 4, 30, 210, 174, Decimal('0.5469'), 'Historically Succesful Franchise'),
#  ('Detroit Pistons', 3, 23, 148, 119, Decimal('0.5543'), 'Historically Succesful Franchise'),
#  ('Cleveland Cavaliers', 1, 19, 118, 93, Decimal('0.5592'), 'Moderately Succesful Franchise'),
#  ('San Antonio Spurs', 5, 35, 212, 166, Decimal('0.5608'), 'Historically Succesful Franchise'),
#  ('Miami Heat', 3, 21, 138, 107, Decimal('0.5633'), 'Historically Succesful Franchise'),
#  ('Chicago Bulls', 6, 26, 166, 120, Decimal('0.5804'), 'Historically Succesful Franchise'),
#  ('Golden State Warriors', 3, 13, 104, 65, Decimal('0.6154'), 'Historically Succesful Franchise'),
#  ('Los Angeles Lakers', 10, 32, 277, 165, Decimal('0.6267'), 'Historically Succesful Franchise')]

# %% [markdown]
# This query was interesting because initiall the way I programmed it, a lot of teams that I would consider to be succesful franchises were not being categorized correctly because of numerous factors such as being a new team or having a lot of recent success. For example a team like the Clippers who I believe is a succesful franchise were being categorized in the bottom tier of the CASE statement even though they have been a playoff competitor in recent memory. To solve this, I added in the `other` tag so the categorization would not be as restrictive. Also, Instead of just looking at championships, I also wanted to make playoff appearnces and playoff winning percentage important when evaluating a franchise.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Explanatory Query 4: rank the top 3 teams by average atttendance per game each season from 2000-2015

# %%
# %%sql
# WITH avgAttendancePerSeasonRanked AS (
#     SELECT
#         season,
#         team,
#         homeAVGAttendancePerGame,
#         RANK() OVER (
#             PARTITION BY season
#             ORDER BY homeAVGAttendancePerGame DESC
#         ) AS seasonAVGAttendanceRank
#     FROM nba_annual_attendance
# )
# SELECT *
# FROM avgAttendancePerSeasonRanked
# WHERE seasonAVGAttendanceRank IN (1,2,3);
# Out:
#  * mysql://admin:***@lmu-dev-01.cenozo6j3rls.us-east-1.rds.amazonaws.com/nba
# 48 rows affected.
# [(2000, 'San Antonio Spurs', 22272, 1),
#  (2000, 'Chicago Bulls', 21674, 2),
#  (2000, 'Portland Trail Blazers', 20277, 3),
#  (2001, 'San Antonio Spurs', 22107, 1),
#  (2001, 'Washington Wizards', 20674, 2),
#  (2001, 'Philadelphia 76ers', 20560, 3),
#  (2002, 'Detroit Pistons', 20470, 1),
#  (2002, 'Washington Wizards', 20172, 2),
#  (2002, 'Dallas Mavericks', 19912, 3),
#  (2003, 'Detroit Pistons', 21290, 1),
#  (2003, 'Dallas Mavericks', 20136, 2),
#  (2003, 'Chicago Bulls', 19736, 3),
#  (2004, 'Detroit Pistons', 22076, 1),
#  (2004, 'Chicago Bulls', 20204, 2),
#  (2004, 'Dallas Mavericks', 20061, 3),
#  (2005, 'Detroit Pistons', 22076, 1),
#  (2005, 'Chicago Bulls', 21188, 2),
#  (2005, 'Dallas Mavericks', 20114, 3),
#  (2006, 'Chicago Bulls', 22252, 1),
#  (2006, 'Detroit Pistons', 22076, 2),
#  (2006, 'Cleveland Cavaliers', 20436, 3),
#  (2007, 'Detroit Pistons', 22076, 1),
#  (2007, 'Chicago Bulls', 21987, 2),
#  (2007, 'Cleveland Cavaliers', 20465, 3),
#  (2008, 'Detroit Pistons', 21877, 1),
#  (2008, 'Chicago Bulls', 21197, 2),
#  (2008, 'Portland Trail Blazers', 20524, 3),
#  (2009, 'Chicago Bulls', 20725, 1),
#  (2009, 'Cleveland Cavaliers', 20562, 2),
#  (2009, 'Portland Trail Blazers', 20497, 3),
#  (2010, 'Chicago Bulls', 21791, 1),
#  (2010, 'Portland Trail Blazers', 20510, 2),
#  (2010, 'Cleveland Cavaliers', 20112, 3),
#  (2011, 'Chicago Bulls', 22161, 1),
#  (2011, 'Portland Trail Blazers', 20496, 2),
#  (2011, 'Dallas Mavericks', 20334, 3),
#  (2012, 'Chicago Bulls', 21876, 1),
#  (2012, 'Dallas Mavericks', 20036, 2),
#  (2012, 'Miami Heat', 19982, 3),
#  (2013, 'Chicago Bulls', 21716, 1),
#  (2013, 'Dallas Mavericks', 19950, 2),
#  (2013, 'New York Knicks', 19812, 3),
#  (2014, 'Chicago Bulls', 21343, 1),
#  (2014, 'Cleveland Cavaliers', 20562, 2),
#  (2014, 'Dallas Mavericks', 20187, 3),
#  (2015, 'Chicago Bulls', 21820, 1),
#  (2015, 'Cleveland Cavaliers', 20562, 2),
#  (2015, 'Dallas Mavericks', 20143, 3)]

# %% [markdown]
# After running this query, a lot of the results were different that I expected. The biggest suprise was that the Los Angeles Lakers and Clippers did not appear in the top 3 once through 2000-2015 despite the Lakers championship runs and the Clippers lob city era. Also, the Miami Heat only apppeared in the top 3 once during the 2010-2014 big three era. However, one thing that could explain the unexpected results could be arena size. For example, a team like the Bulls who appear on the top 3 list for 14 seasons could have a higher average attendance because they have higher stadium capacity than a team like the Lakers even if the United Center(Chicago Bulls) is filled 80% while the Staples center(Los Angeles Lakers and Clippers) is filled 95%.

# %% [markdown]
# -------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Explanatory Query 5: create a list of the different teams and how many top 3 season they have in the span of 2000 to 2015 based off of average home attendance per game

# %%
# %%sql
# WITH top3RankedSeasonsByAVGAttendance AS (
#     WITH avgAttendancePerSeasonRanked AS (
#     SELECT
#         season,
#         team,
#         homeAVGAttendancePerGame,
#         RANK() OVER (
#             PARTITION BY season
#             ORDER BY homeAVGAttendancePerGame DESC
#         ) AS seasonAVGAttendanceRank
#     FROM nba_annual_attendance
#     )
#     SELECT *
#     FROM avgAttendancePerSeasonRanked
#     WHERE seasonAVGAttendanceRank IN (1,2,3)
# )
# SELECT
#     team,
#     COUNT(team) AS seasonsInTop3AVGAttendancePerGame
# FROM top3RankedSeasonsByAVGAttendance
# GROUP BY team
# ORDER BY seasonsInTop3AVGAttendancePerGame DESC;
# Out:
#  * mysql://admin:***@lmu-dev-01.cenozo6j3rls.us-east-1.rds.amazonaws.com/nba
# 10 rows affected.
# [('Chicago Bulls', 14),
#  ('Dallas Mavericks', 9),
#  ('Detroit Pistons', 7),
#  ('Cleveland Cavaliers', 6),
#  ('Portland Trail Blazers', 5),
#  ('San Antonio Spurs', 2),
#  ('Washington Wizards', 2),
#  ('Philadelphia 76ers', 1),
#  ('Miami Heat', 1),
#  ('New York Knicks', 1)]

# %% [markdown]
# # Part 2 Primary Question

# %% [markdown]
# Primary Question: with the coronavirus how can we evaluate the remaining games for the 2020-2021 NBA season and price the tickets based on stats from each team such as historical attendance, historical ticket prices, historical revenues, and team prestige

# %% [markdown]
# Primary Query 1: create a view of the remaining games for the 2020-2021 season with the home and away team's average ticket costs and the combined average ticket cost of the home and away teams. Then query the view to evaluate whether the combined average ticket cost is above or below the league average and if the home team should price their tickets up or down according to the average ticket cost of the team they are playing.
#
# SQL Features: `VIEW`, `JOIN`, `GROUP BY`, `Subquery`, `CASE`
#
# Business Justification: The purpose of this query would be to help assist an organizations ticketing and sales team determine how they should price their tickets for each game depending on prior ticket data and also the team they are playing against.

# %%
# %%sql
# CREATE OR REPLACE VIEW nbaGamesWithFinancialData AS (
# SELECT *,
#     SUM(homeTeamAverageTicketCost + awayTeamAverageTicketCost) AS combinedAverageTicketCost
#     FROM(
#         SELECT
#             event_id,
#             matchup,
#             home_team,
#             away_team,
#             date,
#             averageTicketCost AS homeTeamAverageTicketCost
#         FROM games g
#         JOIN nba_team_financials ntf
#             ON g.home_team = ntf.teamName) AS homeTeamFinancials
#     JOIN (
#         SELECT
#             event_id AS awayEvent_ID,
#             averageTicketCost AS awayTeamAverageTicketCost
#         FROM games g
#         JOIN nba_team_financials ntf
#             ON g.away_team = ntf.teamName) AS awayTeamFinancials
#     ON homeTeamFinancials.event_id = awayTeamFinancials.awayEvent_ID
#     GROUP BY event_id
#     ORDER BY date
#     );
# SELECT
#     event_id,
#     matchup,
#     date,
#     home_team,
#     away_team,
#     homeTeamAverageTicketCost,
#     awayTeamAverageTicketCost,
#     combinedAverageTicketCost/2 AS proposedAverageTicketPrice,
#     ##how to determine price using both teams average ticket cost, so when a team is playing a team who is better than them and garners more interste (measured by ticket sales) then the tickets will go up but if the opposing team is worse, then the tickets will go down
#     (
#     SELECT
#         AVG(combinedAverageTicketCost/2)
#     FROM nbaGamesWithFinancialData
#     ) AS combinedAverageTicketCostAllTeams,
#     CASE
#         WHEN combinedAverageTicketCost/2 > (
#         SELECT
#             AVG(combinedAverageTicketCost/2)
#         FROM nbaGamesWithFinancialData) THEN 'Above Average'
#         ELSE 'Below Average'
#     END AS pricingComparedToLeagueAverage,
#     CASE
#         WHEN homeTeamAverageTicketCost > awayTeamAverageTicketCost THEN 'Price down'
#         #when a team is playing a team that is worse than them(by looking at their average ticket costs) and if the home team has a greater ticket cost, you can price down the tickets
#         WHEN homeTeamAverageTicketCost < awayTeamAverageTicketCost THEN 'Price up'
#         #when a team is playing a team that is better than them(by looking at their average ticket costs) and if the away team has a greater ticket cost, you can price up the tickets
#     END AS pricingDecision
# FROM nbaGamesWithFinancialData
# GROUP BY event_id
# ORDER BY date;
# Out:
#  * mysql://admin:***@lmu-dev-01.cenozo6j3rls.us-east-1.rds.amazonaws.com/nba
# 0 rows affected.
# 160 rows affected.
# [(49, 'Boston Celtics vs. Chicago Bulls', datetime.date(2021, 4, 19), 'Boston Celtics', 'Chicago Bulls', 154, 133, Decimal('143.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (46, 'Detroit Pistons vs. Cleveland Cavaliers', datetime.date(2021, 4, 19), 'Detroit Pistons', 'Cleveland Cavaliers', 69, 72, Decimal('70.5000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (3, 'Los Angeles Lakers vs. Utah Jazz', datetime.date(2021, 4, 19), 'Los Angeles Lakers', 'Utah Jazz', 473, 117, Decimal('295.0000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (117, 'Indiana Pacers vs. San Antonio Spurs', datetime.date(2021, 4, 19), 'Indiana Pacers', 'San Antonio Spurs', 94, 177, Decimal('135.5000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (5, 'Miami Heat vs. Houston Rockets', datetime.date(2021, 4, 19), 'Miami Heat', 'Houston Rockets', 150, 189, Decimal('169.5000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (106, 'Milwaukee Bucks vs. Phoenix Suns', datetime.date(2021, 4, 19), 'Milwaukee Bucks', 'Phoenix Suns', 132, 85, Decimal('108.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (92, 'Denver Nuggets vs. Memphis Grizzlies', datetime.date(2021, 4, 19), 'Denver Nuggets', 'Memphis Grizzlies', 154, 73, Decimal('113.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (116, 'Atlanta Hawks vs. Orlando Magic', datetime.date(2021, 4, 20), 'Atlanta Hawks', 'Orlando Magic', 107, 87, Decimal('97.0000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (88, 'New York Knicks vs. Charlotte Hornets', datetime.date(2021, 4, 20), 'New York Knicks', 'Charlotte Hornets', 261, 64, Decimal('162.5000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (145, 'San Antonio Spurs v Miami Heat Fiesta Sunglasses Giveaway', datetime.date(2021, 4, 21), 'San Antonio Spurs', 'Miami Heat', 177, 150, Decimal('163.5000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (32, 'Washington Wizards vs. Golden State Warriors', datetime.date(2021, 4, 21), 'Washington Wizards', 'Golden State Warriors', 92, 458, Decimal('275.0000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (2, 'Houston Rockets vs. Utah Jazz', datetime.date(2021, 4, 21), 'Houston Rockets', 'Utah Jazz', 189, 117, Decimal('153.0000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (143, 'Indiana Pacers vs. Oklahoma City Thunder', datetime.date(2021, 4, 21), 'Indiana Pacers', 'Oklahoma City Thunder', 94, 137, Decimal('115.5000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (83, 'New York Knicks vs. Atlanta Hawks', datetime.date(2021, 4, 21), 'New York Knicks', 'Atlanta Hawks', 261, 107, Decimal('184.0000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (25, 'Dallas Mavericks vs. Detroit Pistons', datetime.date(2021, 4, 21), 'Dallas Mavericks', 'Detroit Pistons', 110, 69, Decimal('89.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (22, 'Toronto Raptors vs. Brooklyn Nets', datetime.date(2021, 4, 21), 'Toronto Raptors', 'Brooklyn Nets', 179, 242, Decimal('210.5000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (112, 'Sacramento Kings vs. Minnesota Timberwolves', datetime.date(2021, 4, 21), 'Sacramento Kings', 'Minnesota Timberwolves', 107, 58, Decimal('82.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (23, 'Dallas Mavericks vs. Los Angeles Lakers', datetime.date(2021, 4, 22), 'Dallas Mavericks', 'Los Angeles Lakers', 110, 473, Decimal('291.5000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (47, 'Boston Celtics vs. Phoenix Suns', datetime.date(2021, 4, 22), 'Boston Celtics', 'Phoenix Suns', 154, 85, Decimal('119.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (105, 'Orlando Magic vs. New Orleans Pelicans', datetime.date(2021, 4, 22), 'Orlando Magic', 'New Orleans Pelicans', 87, 105, Decimal('96.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (81, 'San Antonio Spurs vs. Detroit Pistons', datetime.date(2021, 4, 22), 'San Antonio Spurs', 'Detroit Pistons', 177, 69, Decimal('123.0000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (111, 'Milwaukee Bucks vs. Philadelphia 76ers', datetime.date(2021, 4, 22), 'Milwaukee Bucks', 'Philadelphia 76ers', 132, 150, Decimal('141.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (72, 'Charlotte Hornets vs. Cleveland Cavaliers', datetime.date(2021, 4, 23), 'Charlotte Hornets', 'Cleveland Cavaliers', 64, 72, Decimal('68.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (113, 'Atlanta Hawks vs. Miami Heat', datetime.date(2021, 4, 23), 'Atlanta Hawks', 'Miami Heat', 107, 150, Decimal('128.5000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (1, 'Houston Rockets vs. LA Clippers', datetime.date(2021, 4, 23), 'Houston Rockets', 'LA Clippers', 189, 267, Decimal('228.0000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (74, 'Brooklyn Nets vs. Boston Celtics', datetime.date(2021, 4, 23), 'Brooklyn Nets', 'Boston Celtics', 242, 154, Decimal('198.0000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (100, 'Golden State Warriors vs. Denver Nuggets', datetime.date(2021, 4, 23), 'Golden State Warriors', 'Denver Nuggets', 458, 154, Decimal('306.0000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (45, 'Miami Heat vs. Chicago Bulls', datetime.date(2021, 4, 24), 'Miami Heat', 'Chicago Bulls', 150, 133, Decimal('141.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (86, 'New York Knicks vs. Toronto Raptors', datetime.date(2021, 4, 24), 'New York Knicks', 'Toronto Raptors', 261, 179, Decimal('220.0000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (26, 'Dallas Mavericks vs. Los Angeles Lakers', datetime.date(2021, 4, 24), 'Dallas Mavericks', 'Los Angeles Lakers', 110, 473, Decimal('291.5000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (93, 'Denver Nuggets vs. Houston Rockets', datetime.date(2021, 4, 24), 'Denver Nuggets', 'Houston Rockets', 154, 189, Decimal('171.5000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (63, 'Indiana Pacers vs. Detroit Pistons', datetime.date(2021, 4, 24), 'Indiana Pacers', 'Detroit Pistons', 94, 69, Decimal('81.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (109, 'Milwaukee Bucks vs. Philadelphia 76ers', datetime.date(2021, 4, 24), 'Milwaukee Bucks', 'Philadelphia 76ers', 132, 150, Decimal('141.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (142, 'Utah Jazz vs. Minnesota Timberwolves', datetime.date(2021, 4, 24), 'Utah Jazz', 'Minnesota Timberwolves', 117, 58, Decimal('87.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (76, 'Washington Wizards vs. Cleveland Cavaliers', datetime.date(2021, 4, 25), 'Washington Wizards', 'Cleveland Cavaliers', 92, 72, Decimal('82.0000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (51, 'Charlotte Hornets vs. Boston Celtics', datetime.date(2021, 4, 25), 'Charlotte Hornets', 'Boston Celtics', 64, 154, Decimal('109.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (132, 'Golden State Warriors vs. Sacramento Kings', datetime.date(2021, 4, 25), 'Golden State Warriors', 'Sacramento Kings', 458, 107, Decimal('282.5000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (152, 'Brooklyn Nets vs. Phoenix Suns', datetime.date(2021, 4, 25), 'Brooklyn Nets', 'Phoenix Suns', 242, 85, Decimal('163.5000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (103, 'Orlando Magic vs. Indiana Pacers', datetime.date(2021, 4, 25), 'Orlando Magic', 'Indiana Pacers', 87, 94, Decimal('90.5000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (115, 'Atlanta Hawks vs. Milwaukee Bucks', datetime.date(2021, 4, 25), 'Atlanta Hawks', 'Milwaukee Bucks', 107, 132, Decimal('119.5000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (57, 'Miami Heat vs. Chicago Bulls', datetime.date(2021, 4, 26), 'Miami Heat', 'Chicago Bulls', 150, 133, Decimal('141.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (61, 'Toronto Raptors vs. Cleveland Cavaliers', datetime.date(2021, 4, 26), 'Toronto Raptors', 'Cleveland Cavaliers', 179, 72, Decimal('125.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (42, 'Sacramento Kings vs. Dallas Mavericks', datetime.date(2021, 4, 26), 'Sacramento Kings', 'Dallas Mavericks', 107, 110, Decimal('108.5000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (4, 'Orlando Magic vs. Los Angeles Lakers', datetime.date(2021, 4, 26), 'Orlando Magic', 'Los Angeles Lakers', 87, 473, Decimal('280.0000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (33, 'Washington Wizards vs. San Antonio Spurs', datetime.date(2021, 4, 26), 'Washington Wizards', 'San Antonio Spurs', 92, 177, Decimal('134.5000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (87, 'New York Knicks vs. Phoenix Suns', datetime.date(2021, 4, 26), 'New York Knicks', 'Phoenix Suns', 261, 85, Decimal('173.0000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (36, 'Detroit Pistons vs. Atlanta Hawks', datetime.date(2021, 4, 26), 'Detroit Pistons', 'Atlanta Hawks', 69, 107, Decimal('88.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (95, 'Denver Nuggets vs. Memphis Grizzlies', datetime.date(2021, 4, 26), 'Denver Nuggets', 'Memphis Grizzlies', 154, 73, Decimal('113.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (64, 'Golden State Warriors vs. Dallas Mavericks', datetime.date(2021, 4, 27), 'Golden State Warriors', 'Dallas Mavericks', 458, 110, Decimal('284.0000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (144, 'Indiana Pacers vs. Portland Trail Blazers', datetime.date(2021, 4, 27), 'Indiana Pacers', 'Portland Trail Blazers', 94, 103, Decimal('98.5000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (66, 'Boston Celtics vs. Oklahoma City Thunder', datetime.date(2021, 4, 27), 'Boston Celtics', 'Oklahoma City Thunder', 154, 137, Decimal('145.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (138, 'Charlotte Hornets vs. Milwaukee Bucks', datetime.date(2021, 4, 27), 'Charlotte Hornets', 'Milwaukee Bucks', 64, 132, Decimal('98.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (28, 'Toronto Raptors vs. Brooklyn Nets', datetime.date(2021, 4, 27), 'Toronto Raptors', 'Brooklyn Nets', 179, 242, Decimal('210.5000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (14, 'Houston Rockets vs. Minnesota Timberwolves', datetime.date(2021, 4, 27), 'Houston Rockets', 'Minnesota Timberwolves', 189, 58, Decimal('123.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (89, 'New York Knicks vs. Chicago Bulls', datetime.date(2021, 4, 28), 'New York Knicks', 'Chicago Bulls', 261, 133, Decimal('197.0000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (140, 'Memphis Grizzlies vs. Portland Trail Blazers', datetime.date(2021, 4, 28), 'Memphis Grizzlies', 'Portland Trail Blazers', 73, 103, Decimal('88.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (114, 'Sacramento Kings vs. Utah Jazz', datetime.date(2021, 4, 28), 'Sacramento Kings', 'Utah Jazz', 107, 117, Decimal('112.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (77, 'Phoenix Suns vs. LA Clippers', datetime.date(2021, 4, 28), 'Phoenix Suns', 'LA Clippers', 85, 267, Decimal('176.0000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (34, 'Washington Wizards vs. Los Angeles Lakers', datetime.date(2021, 4, 28), 'Washington Wizards', 'Los Angeles Lakers', 92, 473, Decimal('282.5000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (120, 'Miami Heat vs. San Antonio Spurs', datetime.date(2021, 4, 28), 'Miami Heat', 'San Antonio Spurs', 150, 177, Decimal('163.5000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (67, 'Boston Celtics vs. Charlotte Hornets', datetime.date(2021, 4, 28), 'Boston Celtics', 'Charlotte Hornets', 154, 64, Decimal('109.0000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (98, 'Denver Nuggets vs. New Orleans Pelicans', datetime.date(2021, 4, 28), 'Denver Nuggets', 'New Orleans Pelicans', 154, 105, Decimal('129.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (31, 'Detroit Pistons vs. Dallas Mavericks', datetime.date(2021, 4, 29), 'Detroit Pistons', 'Dallas Mavericks', 69, 110, Decimal('89.5000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (96, 'Denver Nuggets vs. Toronto Raptors', datetime.date(2021, 4, 29), 'Denver Nuggets', 'Toronto Raptors', 154, 179, Decimal('166.5000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (7, 'Houston Rockets vs. Milwaukee Bucks', datetime.date(2021, 4, 29), 'Houston Rockets', 'Milwaukee Bucks', 189, 132, Decimal('160.5000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (153, 'Indiana Pacers vs. Brooklyn Nets', datetime.date(2021, 4, 29), 'Indiana Pacers', 'Brooklyn Nets', 94, 242, Decimal('168.0000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (154, 'Brooklyn Nets vs. Portland Trail Blazers', datetime.date(2021, 4, 30), 'Brooklyn Nets', 'Portland Trail Blazers', 242, 103, Decimal('172.5000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (125, 'Phoenix Suns vs. Utah Jazz', datetime.date(2021, 4, 30), 'Phoenix Suns', 'Utah Jazz', 85, 117, Decimal('101.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (68, 'Boston Celtics vs. San Antonio Spurs', datetime.date(2021, 4, 30), 'Boston Celtics', 'San Antonio Spurs', 154, 177, Decimal('165.5000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (122, 'Memphis Grizzlies vs. Orlando Magic', datetime.date(2021, 4, 30), 'Memphis Grizzlies', 'Orlando Magic', 73, 87, Decimal('80.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (6, 'Los Angeles Lakers vs. Sacramento Kings', datetime.date(2021, 4, 30), 'Los Angeles Lakers', 'Sacramento Kings', 473, 107, Decimal('290.0000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (62, 'Atlanta Hawks vs. Chicago Bulls', datetime.date(2021, 5, 1), 'Atlanta Hawks', 'Chicago Bulls', 107, 133, Decimal('120.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (0, 'Houston Rockets vs. Golden State Warriors', datetime.date(2021, 5, 1), 'Houston Rockets', 'Golden State Warriors', 189, 458, Decimal('323.5000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (54, 'Dallas Mavericks vs. Washington Wizards', datetime.date(2021, 5, 1), 'Dallas Mavericks', 'Washington Wizards', 110, 92, Decimal('101.0000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (104, 'Orlando Magic vs. Memphis Grizzlies', datetime.date(2021, 5, 1), 'Orlando Magic', 'Memphis Grizzlies', 87, 73, Decimal('80.0000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (69, 'Charlotte Hornets vs. Detroit Pistons', datetime.date(2021, 5, 1), 'Charlotte Hornets', 'Detroit Pistons', 64, 69, Decimal('66.5000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (13, 'Los Angeles Lakers vs. Toronto Raptors', datetime.date(2021, 5, 2), 'Los Angeles Lakers', 'Toronto Raptors', 473, 179, Decimal('326.0000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (12, 'Houston Rockets vs. New York Knicks', datetime.date(2021, 5, 2), 'Houston Rockets', 'New York Knicks', 189, 261, Decimal('225.0000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (137, 'Charlotte Hornets vs. Miami Heat', datetime.date(2021, 5, 2), 'Charlotte Hornets', 'Miami Heat', 64, 150, Decimal('107.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (70, 'Boston Celtics vs. Portland Trail Blazers', datetime.date(2021, 5, 2), 'Boston Celtics', 'Portland Trail Blazers', 154, 103, Decimal('128.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (44, 'Dallas Mavericks vs. Sacramento Kings', datetime.date(2021, 5, 2), 'Dallas Mavericks', 'Sacramento Kings', 110, 107, Decimal('108.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (123, 'Milwaukee Bucks vs. Brooklyn Nets', datetime.date(2021, 5, 2), 'Milwaukee Bucks', 'Brooklyn Nets', 132, 242, Decimal('187.0000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (160, 'San Antonio Spurs v Philadelphia 76ers Fiesta Sock Giveaway', datetime.date(2021, 5, 2), 'San Antonio Spurs', 'Philadelphia 76ers', 177, 150, Decimal('163.5000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (71, 'Memphis Grizzlies vs. New York Knicks', datetime.date(2021, 5, 3), 'Memphis Grizzlies', 'New York Knicks', 73, 261, Decimal('167.0000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (128, 'Atlanta Hawks vs. Portland Trail Blazers', datetime.date(2021, 5, 3), 'Atlanta Hawks', 'Portland Trail Blazers', 107, 103, Decimal('105.0000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (40, 'Detroit Pistons vs. Orlando Magic', datetime.date(2021, 5, 3), 'Detroit Pistons', 'Orlando Magic', 69, 87, Decimal('78.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (24, 'Washington Wizards vs. Indiana Pacers', datetime.date(2021, 5, 3), 'Washington Wizards', 'Indiana Pacers', 92, 94, Decimal('93.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (97, 'Los Angeles Lakers vs. Denver Nuggets', datetime.date(2021, 5, 3), 'Los Angeles Lakers', 'Denver Nuggets', 473, 154, Decimal('313.5000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (30, 'Miami Heat vs. Dallas Mavericks', datetime.date(2021, 5, 4), 'Miami Heat', 'Dallas Mavericks', 150, 110, Decimal('130.0000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (52, 'Detroit Pistons vs. Charlotte Hornets', datetime.date(2021, 5, 4), 'Detroit Pistons', 'Charlotte Hornets', 69, 64, Decimal('66.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (130, 'Milwaukee Bucks vs. Brooklyn Nets', datetime.date(2021, 5, 4), 'Milwaukee Bucks', 'Brooklyn Nets', 132, 242, Decimal('187.0000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (99, 'Denver Nuggets vs. New York Knicks', datetime.date(2021, 5, 5), 'Denver Nuggets', 'New York Knicks', 154, 261, Decimal('207.5000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (16, 'Orlando Magic vs. Boston Celtics', datetime.date(2021, 5, 5), 'Orlando Magic', 'Boston Celtics', 87, 154, Decimal('120.5000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (11, 'Milwaukee Bucks vs. Washington Wizards', datetime.date(2021, 5, 5), 'Milwaukee Bucks', 'Washington Wizards', 132, 92, Decimal('112.0000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (131, 'Indiana Pacers vs. Sacramento Kings', datetime.date(2021, 5, 5), 'Indiana Pacers', 'Sacramento Kings', 94, 107, Decimal('100.5000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (119, 'Atlanta Hawks vs. Phoenix Suns', datetime.date(2021, 5, 5), 'Atlanta Hawks', 'Phoenix Suns', 107, 85, Decimal('96.0000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (17, 'Houston Rockets vs. Philadelphia 76ers', datetime.date(2021, 5, 5), 'Houston Rockets', 'Philadelphia 76ers', 189, 150, Decimal('169.5000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (80, 'Charlotte Hornets vs. Chicago Bulls', datetime.date(2021, 5, 6), 'Charlotte Hornets', 'Chicago Bulls', 64, 133, Decimal('98.5000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (147, 'Golden State Warriors vs. Oklahoma City Thunder', datetime.date(2021, 5, 6), 'Golden State Warriors', 'Oklahoma City Thunder', 458, 137, Decimal('297.5000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (19, 'Toronto Raptors vs. Washington Wizards', datetime.date(2021, 5, 6), 'Toronto Raptors', 'Washington Wizards', 179, 92, Decimal('135.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (127, 'Indiana Pacers vs. Atlanta Hawks', datetime.date(2021, 5, 6), 'Indiana Pacers', 'Atlanta Hawks', 94, 107, Decimal('100.5000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (39, 'Detroit Pistons vs. Memphis Grizzlies', datetime.date(2021, 5, 6), 'Detroit Pistons', 'Memphis Grizzlies', 69, 73, Decimal('71.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (73, 'Dallas Mavericks vs. Brooklyn Nets', datetime.date(2021, 5, 6), 'Dallas Mavericks', 'Brooklyn Nets', 110, 242, Decimal('176.0000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (56, 'Dallas Mavericks vs. Cleveland Cavaliers', datetime.date(2021, 5, 7), 'Dallas Mavericks', 'Cleveland Cavaliers', 110, 72, Decimal('91.0000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (78, 'Phoenix Suns vs. New York Knicks', datetime.date(2021, 5, 7), 'Phoenix Suns', 'New York Knicks', 85, 261, Decimal('173.0000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (29, 'Milwaukee Bucks vs. Houston Rockets', datetime.date(2021, 5, 7), 'Milwaukee Bucks', 'Houston Rockets', 132, 189, Decimal('160.5000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (141, 'Charlotte Hornets vs. Orlando Magic', datetime.date(2021, 5, 7), 'Charlotte Hornets', 'Orlando Magic', 64, 87, Decimal('75.5000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (118, 'Miami Heat vs. Minnesota Timberwolves', datetime.date(2021, 5, 7), 'Miami Heat', 'Minnesota Timberwolves', 150, 58, Decimal('104.0000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (148, 'Golden State Warriors vs. Oklahoma City Thunder', datetime.date(2021, 5, 8), 'Golden State Warriors', 'Oklahoma City Thunder', 458, 137, Decimal('297.5000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (27, 'Indiana Pacers vs. Washington Wizards', datetime.date(2021, 5, 8), 'Indiana Pacers', 'Washington Wizards', 94, 92, Decimal('93.0000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (8, 'Toronto Raptors vs. Memphis Grizzlies', datetime.date(2021, 5, 8), 'Toronto Raptors', 'Memphis Grizzlies', 179, 73, Decimal('126.0000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (102, 'Denver Nuggets vs. Brooklyn Nets', datetime.date(2021, 5, 8), 'Denver Nuggets', 'Brooklyn Nets', 154, 242, Decimal('198.0000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (50, 'Detroit Pistons vs. Chicago Bulls', datetime.date(2021, 5, 9), 'Detroit Pistons', 'Chicago Bulls', 69, 133, Decimal('101.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (60, 'Boston Celtics vs. Miami Heat', datetime.date(2021, 5, 9), 'Boston Celtics', 'Miami Heat', 154, 150, Decimal('152.0000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (15, 'Los Angeles Lakers vs. Phoenix Suns', datetime.date(2021, 5, 9), 'Los Angeles Lakers', 'Phoenix Suns', 473, 85, Decimal('279.0000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (150, 'Charlotte Hornets vs. New Orleans Pelicans', datetime.date(2021, 5, 9), 'Charlotte Hornets', 'New Orleans Pelicans', 64, 105, Decimal('84.5000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (107, 'Orlando Magic vs. Minnesota Timberwolves', datetime.date(2021, 5, 9), 'Orlando Magic', 'Minnesota Timberwolves', 87, 58, Decimal('72.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (133, 'Golden State Warriors vs. Utah Jazz', datetime.date(2021, 5, 10), 'Golden State Warriors', 'Utah Jazz', 458, 117, Decimal('287.5000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (21, 'Atlanta Hawks vs. Washington Wizards', datetime.date(2021, 5, 10), 'Atlanta Hawks', 'Washington Wizards', 107, 92, Decimal('99.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (139, 'Memphis Grizzlies vs. New Orleans Pelicans', datetime.date(2021, 5, 10), 'Memphis Grizzlies', 'New Orleans Pelicans', 73, 105, Decimal('89.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (158, 'San Antonio Spurs v Milwaukee Bucks Military Appreciation Night', datetime.date(2021, 5, 10), 'San Antonio Spurs', 'Milwaukee Bucks', 177, 132, Decimal('154.5000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (55, 'Memphis Grizzlies vs. Dallas Mavericks', datetime.date(2021, 5, 11), 'Memphis Grizzlies', 'Dallas Mavericks', 73, 110, Decimal('91.5000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (65, 'Los Angeles Lakers vs. New York Knicks', datetime.date(2021, 5, 11), 'Los Angeles Lakers', 'New York Knicks', 473, 261, Decimal('367.0000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (59, 'Boston Celtics vs. Miami Heat', datetime.date(2021, 5, 11), 'Boston Celtics', 'Miami Heat', 154, 150, Decimal('152.0000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (58, 'Toronto Raptors vs. Los Angeles Clippers', datetime.date(2021, 5, 11), 'Toronto Raptors', 'LA Clippers', 179, 267, Decimal('223.0000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (110, 'Milwaukee Bucks vs. Orlando Magic', datetime.date(2021, 5, 11), 'Milwaukee Bucks', 'Orlando Magic', 132, 87, Decimal('109.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (134, 'Golden State Warriors vs. Phoenix Suns', datetime.date(2021, 5, 11), 'Golden State Warriors', 'Phoenix Suns', 458, 85, Decimal('271.5000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (146, 'Indiana Pacers vs. Philadelphia 76ers', datetime.date(2021, 5, 11), 'Indiana Pacers', 'Philadelphia 76ers', 94, 150, Decimal('122.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (41, 'Detroit Pistons vs. Minnesota Timberwolves', datetime.date(2021, 5, 11), 'Detroit Pistons', 'Minnesota Timberwolves', 69, 58, Decimal('63.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (101, 'Charlotte Hornets vs. Denver Nuggets', datetime.date(2021, 5, 11), 'Charlotte Hornets', 'Denver Nuggets', 64, 154, Decimal('109.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (159, 'Brooklyn Nets vs. San Antonio Spurs', datetime.date(2021, 5, 12), 'Brooklyn Nets', 'San Antonio Spurs', 242, 177, Decimal('209.5000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (43, 'Los Angeles Lakers vs. Houston Rockets', datetime.date(2021, 5, 12), 'Los Angeles Lakers', 'Houston Rockets', 473, 189, Decimal('331.0000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (20, 'Atlanta Hawks vs. Washington Wizards', datetime.date(2021, 5, 12), 'Atlanta Hawks', 'Washington Wizards', 107, 92, Decimal('99.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (53, 'Dallas Mavericks vs. New Orleans Pelicans', datetime.date(2021, 5, 12), 'Dallas Mavericks', 'New Orleans Pelicans', 110, 105, Decimal('107.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (151, 'Phoenix Suns vs. Portland Trail Blazers', datetime.date(2021, 5, 13), 'Phoenix Suns', 'Portland Trail Blazers', 85, 103, Decimal('94.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (79, 'Charlotte Hornets vs. LA Clippers', datetime.date(2021, 5, 13), 'Charlotte Hornets', 'LA Clippers', 64, 267, Decimal('165.5000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (91, 'New York Knicks vs. San Antonio Spurs', datetime.date(2021, 5, 13), 'New York Knicks', 'San Antonio Spurs', 261, 177, Decimal('219.0000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (121, 'Atlanta Hawks vs. Orlando Magic', datetime.date(2021, 5, 13), 'Atlanta Hawks', 'Orlando Magic', 107, 87, Decimal('97.0000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (129, 'Memphis Grizzlies vs. Sacramento Kings', datetime.date(2021, 5, 13), 'Memphis Grizzlies', 'Sacramento Kings', 73, 107, Decimal('90.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (135, 'Indiana Pacers vs. Milwaukee Bucks', datetime.date(2021, 5, 13), 'Indiana Pacers', 'Milwaukee Bucks', 94, 132, Decimal('113.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (124, 'Miami Heat vs. Philadelphia 76ers', datetime.date(2021, 5, 13), 'Miami Heat', 'Philadelphia 76ers', 150, 150, Decimal('150.0000'), Decimal('154.28750000'), 'Below Average', None),
#  (75, 'Washington Wizards vs. Cleveland Cavaliers', datetime.date(2021, 5, 14), 'Washington Wizards', 'Cleveland Cavaliers', 92, 72, Decimal('82.0000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (38, 'Dallas Mavericks vs. Toronto Raptors', datetime.date(2021, 5, 14), 'Dallas Mavericks', 'Toronto Raptors', 110, 179, Decimal('144.5000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (9, 'Houston Rockets vs. LA Clippers', datetime.date(2021, 5, 14), 'Houston Rockets', 'LA Clippers', 189, 267, Decimal('228.0000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (126, 'Memphis Grizzlies vs. Sacramento Kings', datetime.date(2021, 5, 14), 'Memphis Grizzlies', 'Sacramento Kings', 73, 107, Decimal('90.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (149, 'Golden State Warriors vs. New Orleans Pelicans', datetime.date(2021, 5, 14), 'Golden State Warriors', 'New Orleans Pelicans', 458, 105, Decimal('281.5000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (94, 'Detroit Pistons vs. Denver Nuggets', datetime.date(2021, 5, 14), 'Detroit Pistons', 'Denver Nuggets', 69, 154, Decimal('111.5000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (82, 'Brooklyn Nets vs. Chicago Bulls', datetime.date(2021, 5, 15), 'Brooklyn Nets', 'Chicago Bulls', 242, 133, Decimal('187.5000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (108, 'Milwaukee Bucks vs. Miami Heat', datetime.date(2021, 5, 15), 'Milwaukee Bucks', 'Miami Heat', 132, 150, Decimal('141.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (18, 'Indiana Pacers vs. Los Angeles Lakers', datetime.date(2021, 5, 15), 'Indiana Pacers', 'Los Angeles Lakers', 94, 473, Decimal('283.5000'), Decimal('154.28750000'), 'Above Average', 'Price up'),
#  (90, 'New York Knicks vs. Charlotte Hornets', datetime.date(2021, 5, 15), 'New York Knicks', 'Charlotte Hornets', 261, 64, Decimal('162.5000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (157, 'San Antonio Spurs v Phoenix Suns Tim Duncan Hall of Fame Night', datetime.date(2021, 5, 15), 'San Antonio Spurs', 'Phoenix Suns', 177, 85, Decimal('131.0000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (84, 'Brooklyn Nets vs. Cleveland Cavaliers', datetime.date(2021, 5, 16), 'Brooklyn Nets', 'Cleveland Cavaliers', 242, 72, Decimal('157.0000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (37, 'Detroit Pistons vs. Miami Heat', datetime.date(2021, 5, 16), 'Detroit Pistons', 'Miami Heat', 69, 150, Decimal('109.5000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (85, 'New York Knicks vs. Boston Celtics', datetime.date(2021, 5, 16), 'New York Knicks', 'Boston Celtics', 261, 154, Decimal('207.5000'), Decimal('154.28750000'), 'Above Average', 'Price down'),
#  (48, 'Atlanta Hawks vs. Houston Rockets', datetime.date(2021, 5, 16), 'Atlanta Hawks', 'Houston Rockets', 107, 189, Decimal('148.0000'), Decimal('154.28750000'), 'Below Average', 'Price up'),
#  (35, 'Washington Wizards vs. Charlotte Hornets', datetime.date(2021, 5, 16), 'Washington Wizards', 'Charlotte Hornets', 92, 64, Decimal('78.0000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (161, 'San Antonio Spurs v Phoenix Suns Fiesta Court Beach Towels Giveaway', datetime.date(2021, 5, 16), 'San Antonio Spurs', 'Phoenix Suns', 177, 85, Decimal('131.0000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (10, 'Toronto Raptors vs. Indiana Pacers', datetime.date(2021, 5, 16), 'Toronto Raptors', 'Indiana Pacers', 179, 94, Decimal('136.5000'), Decimal('154.28750000'), 'Below Average', 'Price down'),
#  (136, 'Golden State Warriors vs. Memphis Grizzlies', datetime.date(2021, 5, 16), 'Golden State Warriors', 'Memphis Grizzlies', 458, 73, Decimal('265.5000'), Decimal('154.28750000'), 'Above Average', 'Price down')]

# %% [markdown]
# Reccomendation: Historical ticket prices from the home and away team should not be the only factors that should be used in determining ticket pricing but can be helpful. Using the data from the pricingDecision column, a team could get an idea about if they should price the tickets up or down. It is important however to remember that other factors influence ticket prices such as day of the week, injuries, supply and demand, time of the game, whether the game is going to be on national television, and team record at the time of the game and should be used together with the historical data.

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Supporting Query 1: How are the 30 NBA teams ranked based on average total attendance across all seasons from 2000-2015
#
# SQL Features: `Common Table Expressoin`, `Window Function`, `GROUP BY`
#
# Business Justification: This query can give us a better picture of which teams are more popular and in demand so we can price tickets accordingly to the level of popularity. It also can give us a picture of teams who are historically popular from the 2000s on because there is a market for fans from the 2000s as well.

# %%
# %%sql
# WITH averageAttendance2000to2015 AS (
#     SELECT
#         team,
#         FORMAT(AVG(homeAttendance),2) AS averageAttendanceAllYears
#     FROM nba_annual_attendance naa
#     GROUP BY team
#     ORDER BY averageAttendanceAllYears DESC
# )
# SELECT
#     team,
#     averageAttendanceAllYears,
#     RANK() OVER (
#         ORDER BY averageAttendanceAllYears DESC
#     ) AS attendanceRank
# FROM averageAttendance2000to2015;
# Out:
#  * mysql://admin:***@lmu-dev-01.cenozo6j3rls.us-east-1.rds.amazonaws.com/nba
# 30 rows affected.
# [('Chicago Bulls', '854,308.13', 1),
#  ('Dallas Mavericks', '804,256.19', 2),
#  ('New York Knicks', '786,593.63', 3),
#  ('Utah Jazz', '774,440.88', 4),
#  ('Portland Trail Blazers', '768,555.69', 5),
#  ('Los Angeles Lakers', '767,146.06', 6),
#  ('San Antonio Spurs', '763,849.31', 7),
#  ('Detroit Pistons', '753,104.75', 8),
#  ('Miami Heat', '749,901.25', 9),
#  ('Toronto Raptors', '745,869.31', 10),
#  ('Cleveland Cavaliers', '737,237.00', 11),
#  ('Golden State Warriors', '722,596.69', 12),
#  ('LA Clippers', '712,196.13', 13),
#  ('Boston Celtics', '706,866.88', 14),
#  ('Washington Wizards', '705,374.75', 15),
#  ('Phoenix Suns', '693,943.00', 16),
#  ('Oklahoma City Thunder', '680,896.06', 17),
#  ('Denver Nuggets', '670,653.63', 18),
#  ('Philadelphia 76ers', '670,088.06', 19),
#  ('Orlando Magic', '667,400.88', 20),
#  ('Houston Rockets', '647,578.44', 21),
#  ('Minnesota Timberwolves', '643,243.81', 22),
#  ('Sacramento Kings', '641,497.19', 23),
#  ('Milwaukee Bucks', '636,031.13', 24),
#  ('Indiana Pacers', '635,745.31', 25),
#  ('Charlotte Hornets', '629,707.75', 26),
#  ('New Orleans Pelicans', '623,506.81', 27),
#  ('Brooklyn Nets', '621,443.06', 28),
#  ('Memphis Grizzlies', '612,215.06', 29),
#  ('Atlanta Hawks', '612,026.63', 30)]

# %% [markdown]
# Reccomendation: Looking at these results we can get a better idea of who the most popular teams from 2000-2015 were. So when we are planning to price tickets for home games that include some of the teams in the top 10, we can price accordingly and increase the prices or if we are playing teams in the bottom 10 we can lower the prices potenatilly. It is important to know that there are numerous other factors that effect the pricing of tickets such as day of the week, injuries, supply and demand, time of the game, whether the game is going to be on national television, and team record and should be included in the determination of pricing along with the historical data from the primary query and the supporting query 1.

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# Supporting Query 2: For the remaining games of the 2020-2021 season, how much revenue did the home team and away team make during the 2018-2019 and 2019-2020 seasons and how much is the total team value of each?
#
# SQL Features: `CTE`, `JOIN`
#
# Business Justification: This query can show how much regvenue each time is generating per matchup and each of their valuation. With this data we could get look at a matchup and get an idea of the markets and demand of the opposing team and then make pricing decisions based on the market size regardless of factors like team record. For example, the New York Knicks will always generate high revenues, packed arenas, and high ticket prices regardless of their teams success because of the market they are in.

# %%
# %%sql
# WITH homeTeamInfo AS (
#     SELECT
#         event_id,
#         matchup,
#         home_team,
#         away_team,
#         date,
#         `2019_2020_Revenue(millions)` AS home_team_2019_2020_Revenue,
#         `2018_2019_Revenue(millions)` AS home_team_2018_2019_Revenue,
#         `totalTeamValue(millions)` AS homeTeamTotalValue
#     FROM games g
#     JOIN nba_team_financials ntf
#         ON g.home_team = ntf.teamName
# )
# SELECT *
# FROM homeTeamInfo
# JOIN (
#     SELECT
#         event_id,
#         `2019_2020_Revenue(millions)` AS away_team_2019_2020_Revenue,
#         `2018_2019_Revenue(millions)` AS away_team_2018_2019_Revenue,
#         `totalTeamValue(millions)` AS awayTeamTotalValue
#     FROM games g
#     JOIN nba_team_financials ntf
#         ON g.away_team = ntf.teamName) AS awayTeamInfo
#     ON homeTeamInfo.event_id = awayTeamInfo.event_id
# ORDER BY date;
# Out:
#  * mysql://admin:***@lmu-dev-01.cenozo6j3rls.us-east-1.rds.amazonaws.com/nba
# 160 rows affected.
# [(49, 'Boston Celtics vs. Chicago Bulls', 'Boston Celtics', 'Chicago Bulls', datetime.date(2021, 4, 19), 308, 341, 3180, 49, 304, 322, 3140),
#  (46, 'Detroit Pistons vs. Cleveland Cavaliers', 'Detroit Pistons', 'Cleveland Cavaliers', datetime.date(2021, 4, 19), 258, 279, 1740, 46, 256, 293, 1740),
#  (3, 'Los Angeles Lakers vs. Utah Jazz', 'Los Angeles Lakers', 'Utah Jazz', datetime.date(2021, 4, 19), 418, 459, 5140, 3, 251, 273, 1710),
#  (117, 'Indiana Pacers vs. San Antonio Spurs', 'Indiana Pacers', 'San Antonio Spurs', datetime.date(2021, 4, 19), 228, 249, 1550, 117, 279, 298, 2050),
#  (5, 'Miami Heat vs. Houston Rockets', 'Miami Heat', 'Houston Rockets', datetime.date(2021, 4, 19), 283, 310, 2380, 5, 344, 385, 2770),
#  (106, 'Milwaukee Bucks vs. Phoenix Suns', 'Milwaukee Bucks', 'Phoenix Suns', datetime.date(2021, 4, 19), 259, 299, 1860, 106, 231, 249, 1640),
#  (92, 'Denver Nuggets vs. Memphis Grizzlies', 'Denver Nuggets', 'Memphis Grizzlies', datetime.date(2021, 4, 19), 226, 259, 1770, 92, 213, 229, 1360),
#  (116, 'Atlanta Hawks vs. Orlando Magic', 'Atlanta Hawks', 'Orlando Magic', datetime.date(2021, 4, 20), 236, 254, 1540, 116, 227, 249, 1530),
#  (88, 'New York Knicks vs. Charlotte Hornets', 'New York Knicks', 'Charlotte Hornets', datetime.date(2021, 4, 20), 428, 472, 5420, 88, 233, 251, 1510),
#  (145, 'San Antonio Spurs v Miami Heat Fiesta Sunglasses Giveaway', 'San Antonio Spurs', 'Miami Heat', datetime.date(2021, 4, 21), 279, 298, 2050, 145, 283, 310, 2380),
#  (32, 'Washington Wizards vs. Golden State Warriors', 'Washington Wizards', 'Golden State Warriors', datetime.date(2021, 4, 21), 247, 278, 2050, 32, 434, 444, 5210),
#  (2, 'Houston Rockets vs. Utah Jazz', 'Houston Rockets', 'Utah Jazz', datetime.date(2021, 4, 21), 344, 385, 2770, 2, 251, 273, 1710),
#  (143, 'Indiana Pacers vs. Oklahoma City Thunder', 'Indiana Pacers', 'Oklahoma City Thunder', datetime.date(2021, 4, 21), 228, 249, 1550, 143, 257, 280, 1660),
#  (83, 'New York Knicks vs. Atlanta Hawks', 'New York Knicks', 'Atlanta Hawks', datetime.date(2021, 4, 21), 428, 472, 5420, 83, 236, 254, 1540),
#  (25, 'Dallas Mavericks vs. Detroit Pistons', 'Dallas Mavericks', 'Detroit Pistons', datetime.date(2021, 4, 21), 296, 322, 2580, 25, 258, 279, 1740),
#  (22, 'Toronto Raptors vs. Brooklyn Nets', 'Toronto Raptors', 'Brooklyn Nets', datetime.date(2021, 4, 21), 292, 341, 2550, 22, 283, 312, 3400),
#  (112, 'Sacramento Kings vs. Minnesota Timberwolves', 'Sacramento Kings', 'Minnesota Timberwolves', datetime.date(2021, 4, 21), 275, 298, 1840, 112, 218, 234, 1430),
#  (23, 'Dallas Mavericks vs. Los Angeles Lakers', 'Dallas Mavericks', 'Los Angeles Lakers', datetime.date(2021, 4, 22), 296, 322, 2580, 23, 418, 459, 5140),
#  (47, 'Boston Celtics vs. Phoenix Suns', 'Boston Celtics', 'Phoenix Suns', datetime.date(2021, 4, 22), 308, 341, 3180, 47, 231, 249, 1640),
#  (105, 'Orlando Magic vs. New Orleans Pelicans', 'Orlando Magic', 'New Orleans Pelicans', datetime.date(2021, 4, 22), 227, 249, 1530, 105, 213, 229, 1350),
#  (81, 'San Antonio Spurs vs. Detroit Pistons', 'San Antonio Spurs', 'Detroit Pistons', datetime.date(2021, 4, 22), 279, 298, 2050, 81, 258, 279, 1740),
#  (111, 'Milwaukee Bucks vs. Philadelphia 76ers', 'Milwaukee Bucks', 'Philadelphia 76ers', datetime.date(2021, 4, 22), 259, 299, 1860, 111, 284, 312, 2500),
#  (72, 'Charlotte Hornets vs. Cleveland Cavaliers', 'Charlotte Hornets', 'Cleveland Cavaliers', datetime.date(2021, 4, 23), 233, 251, 1510, 72, 256, 293, 1740),
#  (113, 'Atlanta Hawks vs. Miami Heat', 'Atlanta Hawks', 'Miami Heat', datetime.date(2021, 4, 23), 236, 254, 1540, 113, 283, 310, 2380),
#  (1, 'Houston Rockets vs. LA Clippers', 'Houston Rockets', 'LA Clippers', datetime.date(2021, 4, 23), 344, 385, 2770, 1, 297, 300, 2630),
#  (74, 'Brooklyn Nets vs. Boston Celtics', 'Brooklyn Nets', 'Boston Celtics', datetime.date(2021, 4, 23), 283, 312, 3400, 74, 308, 341, 3180),
#  (100, 'Golden State Warriors vs. Denver Nuggets', 'Golden State Warriors', 'Denver Nuggets', datetime.date(2021, 4, 23), 434, 444, 5210, 100, 226, 259, 1770),
#  (45, 'Miami Heat vs. Chicago Bulls', 'Miami Heat', 'Chicago Bulls', datetime.date(2021, 4, 24), 283, 310, 2380, 45, 304, 322, 3140),
#  (86, 'New York Knicks vs. Toronto Raptors', 'New York Knicks', 'Toronto Raptors', datetime.date(2021, 4, 24), 428, 472, 5420, 86, 292, 341, 2550),
#  (26, 'Dallas Mavericks vs. Los Angeles Lakers', 'Dallas Mavericks', 'Los Angeles Lakers', datetime.date(2021, 4, 24), 296, 322, 2580, 26, 418, 459, 5140),
#  (93, 'Denver Nuggets vs. Houston Rockets', 'Denver Nuggets', 'Houston Rockets', datetime.date(2021, 4, 24), 226, 259, 1770, 93, 344, 385, 2770),
#  (63, 'Indiana Pacers vs. Detroit Pistons', 'Indiana Pacers', 'Detroit Pistons', datetime.date(2021, 4, 24), 228, 249, 1550, 63, 258, 279, 1740),
#  (109, 'Milwaukee Bucks vs. Philadelphia 76ers', 'Milwaukee Bucks', 'Philadelphia 76ers', datetime.date(2021, 4, 24), 259, 299, 1860, 109, 284, 312, 2500),
#  (142, 'Utah Jazz vs. Minnesota Timberwolves', 'Utah Jazz', 'Minnesota Timberwolves', datetime.date(2021, 4, 24), 251, 273, 1710, 142, 218, 234, 1430),
#  (76, 'Washington Wizards vs. Cleveland Cavaliers', 'Washington Wizards', 'Cleveland Cavaliers', datetime.date(2021, 4, 25), 247, 278, 2050, 76, 256, 293, 1740),
#  (51, 'Charlotte Hornets vs. Boston Celtics', 'Charlotte Hornets', 'Boston Celtics', datetime.date(2021, 4, 25), 233, 251, 1510, 51, 308, 341, 3180),
#  (132, 'Golden State Warriors vs. Sacramento Kings', 'Golden State Warriors', 'Sacramento Kings', datetime.date(2021, 4, 25), 434, 444, 5210, 132, 275, 298, 1840),
#  (152, 'Brooklyn Nets vs. Phoenix Suns', 'Brooklyn Nets', 'Phoenix Suns', datetime.date(2021, 4, 25), 283, 312, 3400, 152, 231, 249, 1640),
#  (103, 'Orlando Magic vs. Indiana Pacers', 'Orlando Magic', 'Indiana Pacers', datetime.date(2021, 4, 25), 227, 249, 1530, 103, 228, 249, 1550),
#  (115, 'Atlanta Hawks vs. Milwaukee Bucks', 'Atlanta Hawks', 'Milwaukee Bucks', datetime.date(2021, 4, 25), 236, 254, 1540, 115, 259, 299, 1860),
#  (57, 'Miami Heat vs. Chicago Bulls', 'Miami Heat', 'Chicago Bulls', datetime.date(2021, 4, 26), 283, 310, 2380, 57, 304, 322, 3140),
#  (61, 'Toronto Raptors vs. Cleveland Cavaliers', 'Toronto Raptors', 'Cleveland Cavaliers', datetime.date(2021, 4, 26), 292, 341, 2550, 61, 256, 293, 1740),
#  (42, 'Sacramento Kings vs. Dallas Mavericks', 'Sacramento Kings', 'Dallas Mavericks', datetime.date(2021, 4, 26), 275, 298, 1840, 42, 296, 322, 2580),
#  (4, 'Orlando Magic vs. Los Angeles Lakers', 'Orlando Magic', 'Los Angeles Lakers', datetime.date(2021, 4, 26), 227, 249, 1530, 4, 418, 459, 5140),
#  (33, 'Washington Wizards vs. San Antonio Spurs', 'Washington Wizards', 'San Antonio Spurs', datetime.date(2021, 4, 26), 247, 278, 2050, 33, 279, 298, 2050),
#  (87, 'New York Knicks vs. Phoenix Suns', 'New York Knicks', 'Phoenix Suns', datetime.date(2021, 4, 26), 428, 472, 5420, 87, 231, 249, 1640),
#  (36, 'Detroit Pistons vs. Atlanta Hawks', 'Detroit Pistons', 'Atlanta Hawks', datetime.date(2021, 4, 26), 258, 279, 1740, 36, 236, 254, 1540),
#  (95, 'Denver Nuggets vs. Memphis Grizzlies', 'Denver Nuggets', 'Memphis Grizzlies', datetime.date(2021, 4, 26), 226, 259, 1770, 95, 213, 229, 1360),
#  (64, 'Golden State Warriors vs. Dallas Mavericks', 'Golden State Warriors', 'Dallas Mavericks', datetime.date(2021, 4, 27), 434, 444, 5210, 64, 296, 322, 2580),
#  (144, 'Indiana Pacers vs. Portland Trail Blazers', 'Indiana Pacers', 'Portland Trail Blazers', datetime.date(2021, 4, 27), 228, 249, 1550, 144, 258, 298, 1910),
#  (66, 'Boston Celtics vs. Oklahoma City Thunder', 'Boston Celtics', 'Oklahoma City Thunder', datetime.date(2021, 4, 27), 308, 341, 3180, 66, 257, 280, 1660),
#  (138, 'Charlotte Hornets vs. Milwaukee Bucks', 'Charlotte Hornets', 'Milwaukee Bucks', datetime.date(2021, 4, 27), 233, 251, 1510, 138, 259, 299, 1860),
#  (28, 'Toronto Raptors vs. Brooklyn Nets', 'Toronto Raptors', 'Brooklyn Nets', datetime.date(2021, 4, 27), 292, 341, 2550, 28, 283, 312, 3400),
#  (14, 'Houston Rockets vs. Minnesota Timberwolves', 'Houston Rockets', 'Minnesota Timberwolves', datetime.date(2021, 4, 27), 344, 385, 2770, 14, 218, 234, 1430),
#  (89, 'New York Knicks vs. Chicago Bulls', 'New York Knicks', 'Chicago Bulls', datetime.date(2021, 4, 28), 428, 472, 5420, 89, 304, 322, 3140),
#  (140, 'Memphis Grizzlies vs. Portland Trail Blazers', 'Memphis Grizzlies', 'Portland Trail Blazers', datetime.date(2021, 4, 28), 213, 229, 1360, 140, 258, 298, 1910),
#  (114, 'Sacramento Kings vs. Utah Jazz', 'Sacramento Kings', 'Utah Jazz', datetime.date(2021, 4, 28), 275, 298, 1840, 114, 251, 273, 1710),
#  (77, 'Phoenix Suns vs. LA Clippers', 'Phoenix Suns', 'LA Clippers', datetime.date(2021, 4, 28), 231, 249, 1640, 77, 297, 300, 2630),
#  (34, 'Washington Wizards vs. Los Angeles Lakers', 'Washington Wizards', 'Los Angeles Lakers', datetime.date(2021, 4, 28), 247, 278, 2050, 34, 418, 459, 5140),
#  (120, 'Miami Heat vs. San Antonio Spurs', 'Miami Heat', 'San Antonio Spurs', datetime.date(2021, 4, 28), 283, 310, 2380, 120, 279, 298, 2050),
#  (67, 'Boston Celtics vs. Charlotte Hornets', 'Boston Celtics', 'Charlotte Hornets', datetime.date(2021, 4, 28), 308, 341, 3180, 67, 233, 251, 1510),
#  (98, 'Denver Nuggets vs. New Orleans Pelicans', 'Denver Nuggets', 'New Orleans Pelicans', datetime.date(2021, 4, 28), 226, 259, 1770, 98, 213, 229, 1350),
#  (31, 'Detroit Pistons vs. Dallas Mavericks', 'Detroit Pistons', 'Dallas Mavericks', datetime.date(2021, 4, 29), 258, 279, 1740, 31, 296, 322, 2580),
#  (96, 'Denver Nuggets vs. Toronto Raptors', 'Denver Nuggets', 'Toronto Raptors', datetime.date(2021, 4, 29), 226, 259, 1770, 96, 292, 341, 2550),
#  (7, 'Houston Rockets vs. Milwaukee Bucks', 'Houston Rockets', 'Milwaukee Bucks', datetime.date(2021, 4, 29), 344, 385, 2770, 7, 259, 299, 1860),
#  (153, 'Indiana Pacers vs. Brooklyn Nets', 'Indiana Pacers', 'Brooklyn Nets', datetime.date(2021, 4, 29), 228, 249, 1550, 153, 283, 312, 3400),
#  (154, 'Brooklyn Nets vs. Portland Trail Blazers', 'Brooklyn Nets', 'Portland Trail Blazers', datetime.date(2021, 4, 30), 283, 312, 3400, 154, 258, 298, 1910),
#  (125, 'Phoenix Suns vs. Utah Jazz', 'Phoenix Suns', 'Utah Jazz', datetime.date(2021, 4, 30), 231, 249, 1640, 125, 251, 273, 1710),
#  (68, 'Boston Celtics vs. San Antonio Spurs', 'Boston Celtics', 'San Antonio Spurs', datetime.date(2021, 4, 30), 308, 341, 3180, 68, 279, 298, 2050),
#  (122, 'Memphis Grizzlies vs. Orlando Magic', 'Memphis Grizzlies', 'Orlando Magic', datetime.date(2021, 4, 30), 213, 229, 1360, 122, 227, 249, 1530),
#  (6, 'Los Angeles Lakers vs. Sacramento Kings', 'Los Angeles Lakers', 'Sacramento Kings', datetime.date(2021, 4, 30), 418, 459, 5140, 6, 275, 298, 1840),
#  (62, 'Atlanta Hawks vs. Chicago Bulls', 'Atlanta Hawks', 'Chicago Bulls', datetime.date(2021, 5, 1), 236, 254, 1540, 62, 304, 322, 3140),
#  (0, 'Houston Rockets vs. Golden State Warriors', 'Houston Rockets', 'Golden State Warriors', datetime.date(2021, 5, 1), 344, 385, 2770, 0, 434, 444, 5210),
#  (54, 'Dallas Mavericks vs. Washington Wizards', 'Dallas Mavericks', 'Washington Wizards', datetime.date(2021, 5, 1), 296, 322, 2580, 54, 247, 278, 2050),
#  (104, 'Orlando Magic vs. Memphis Grizzlies', 'Orlando Magic', 'Memphis Grizzlies', datetime.date(2021, 5, 1), 227, 249, 1530, 104, 213, 229, 1360),
#  (69, 'Charlotte Hornets vs. Detroit Pistons', 'Charlotte Hornets', 'Detroit Pistons', datetime.date(2021, 5, 1), 233, 251, 1510, 69, 258, 279, 1740),
#  (13, 'Los Angeles Lakers vs. Toronto Raptors', 'Los Angeles Lakers', 'Toronto Raptors', datetime.date(2021, 5, 2), 418, 459, 5140, 13, 292, 341, 2550),
#  (12, 'Houston Rockets vs. New York Knicks', 'Houston Rockets', 'New York Knicks', datetime.date(2021, 5, 2), 344, 385, 2770, 12, 428, 472, 5420),
#  (137, 'Charlotte Hornets vs. Miami Heat', 'Charlotte Hornets', 'Miami Heat', datetime.date(2021, 5, 2), 233, 251, 1510, 137, 283, 310, 2380),
#  (70, 'Boston Celtics vs. Portland Trail Blazers', 'Boston Celtics', 'Portland Trail Blazers', datetime.date(2021, 5, 2), 308, 341, 3180, 70, 258, 298, 1910),
#  (44, 'Dallas Mavericks vs. Sacramento Kings', 'Dallas Mavericks', 'Sacramento Kings', datetime.date(2021, 5, 2), 296, 322, 2580, 44, 275, 298, 1840),
#  (123, 'Milwaukee Bucks vs. Brooklyn Nets', 'Milwaukee Bucks', 'Brooklyn Nets', datetime.date(2021, 5, 2), 259, 299, 1860, 123, 283, 312, 3400),
#  (160, 'San Antonio Spurs v Philadelphia 76ers Fiesta Sock Giveaway', 'San Antonio Spurs', 'Philadelphia 76ers', datetime.date(2021, 5, 2), 279, 298, 2050, 160, 284, 312, 2500),
#  (71, 'Memphis Grizzlies vs. New York Knicks', 'Memphis Grizzlies', 'New York Knicks', datetime.date(2021, 5, 3), 213, 229, 1360, 71, 428, 472, 5420),
#  (128, 'Atlanta Hawks vs. Portland Trail Blazers', 'Atlanta Hawks', 'Portland Trail Blazers', datetime.date(2021, 5, 3), 236, 254, 1540, 128, 258, 298, 1910),
#  (40, 'Detroit Pistons vs. Orlando Magic', 'Detroit Pistons', 'Orlando Magic', datetime.date(2021, 5, 3), 258, 279, 1740, 40, 227, 249, 1530),
#  (24, 'Washington Wizards vs. Indiana Pacers', 'Washington Wizards', 'Indiana Pacers', datetime.date(2021, 5, 3), 247, 278, 2050, 24, 228, 249, 1550),
#  (97, 'Los Angeles Lakers vs. Denver Nuggets', 'Los Angeles Lakers', 'Denver Nuggets', datetime.date(2021, 5, 3), 418, 459, 5140, 97, 226, 259, 1770),
#  (30, 'Miami Heat vs. Dallas Mavericks', 'Miami Heat', 'Dallas Mavericks', datetime.date(2021, 5, 4), 283, 310, 2380, 30, 296, 322, 2580),
#  (52, 'Detroit Pistons vs. Charlotte Hornets', 'Detroit Pistons', 'Charlotte Hornets', datetime.date(2021, 5, 4), 258, 279, 1740, 52, 233, 251, 1510),
#  (130, 'Milwaukee Bucks vs. Brooklyn Nets', 'Milwaukee Bucks', 'Brooklyn Nets', datetime.date(2021, 5, 4), 259, 299, 1860, 130, 283, 312, 3400),
#  (99, 'Denver Nuggets vs. New York Knicks', 'Denver Nuggets', 'New York Knicks', datetime.date(2021, 5, 5), 226, 259, 1770, 99, 428, 472, 5420),
#  (16, 'Orlando Magic vs. Boston Celtics', 'Orlando Magic', 'Boston Celtics', datetime.date(2021, 5, 5), 227, 249, 1530, 16, 308, 341, 3180),
#  (11, 'Milwaukee Bucks vs. Washington Wizards', 'Milwaukee Bucks', 'Washington Wizards', datetime.date(2021, 5, 5), 259, 299, 1860, 11, 247, 278, 2050),
#  (131, 'Indiana Pacers vs. Sacramento Kings', 'Indiana Pacers', 'Sacramento Kings', datetime.date(2021, 5, 5), 228, 249, 1550, 131, 275, 298, 1840),
#  (119, 'Atlanta Hawks vs. Phoenix Suns', 'Atlanta Hawks', 'Phoenix Suns', datetime.date(2021, 5, 5), 236, 254, 1540, 119, 231, 249, 1640),
#  (17, 'Houston Rockets vs. Philadelphia 76ers', 'Houston Rockets', 'Philadelphia 76ers', datetime.date(2021, 5, 5), 344, 385, 2770, 17, 284, 312, 2500),
#  (80, 'Charlotte Hornets vs. Chicago Bulls', 'Charlotte Hornets', 'Chicago Bulls', datetime.date(2021, 5, 6), 233, 251, 1510, 80, 304, 322, 3140),
#  (147, 'Golden State Warriors vs. Oklahoma City Thunder', 'Golden State Warriors', 'Oklahoma City Thunder', datetime.date(2021, 5, 6), 434, 444, 5210, 147, 257, 280, 1660),
#  (19, 'Toronto Raptors vs. Washington Wizards', 'Toronto Raptors', 'Washington Wizards', datetime.date(2021, 5, 6), 292, 341, 2550, 19, 247, 278, 2050),
#  (127, 'Indiana Pacers vs. Atlanta Hawks', 'Indiana Pacers', 'Atlanta Hawks', datetime.date(2021, 5, 6), 228, 249, 1550, 127, 236, 254, 1540),
#  (39, 'Detroit Pistons vs. Memphis Grizzlies', 'Detroit Pistons', 'Memphis Grizzlies', datetime.date(2021, 5, 6), 258, 279, 1740, 39, 213, 229, 1360),
#  (73, 'Dallas Mavericks vs. Brooklyn Nets', 'Dallas Mavericks', 'Brooklyn Nets', datetime.date(2021, 5, 6), 296, 322, 2580, 73, 283, 312, 3400),
#  (56, 'Dallas Mavericks vs. Cleveland Cavaliers', 'Dallas Mavericks', 'Cleveland Cavaliers', datetime.date(2021, 5, 7), 296, 322, 2580, 56, 256, 293, 1740),
#  (78, 'Phoenix Suns vs. New York Knicks', 'Phoenix Suns', 'New York Knicks', datetime.date(2021, 5, 7), 231, 249, 1640, 78, 428, 472, 5420),
#  (29, 'Milwaukee Bucks vs. Houston Rockets', 'Milwaukee Bucks', 'Houston Rockets', datetime.date(2021, 5, 7), 259, 299, 1860, 29, 344, 385, 2770),
#  (141, 'Charlotte Hornets vs. Orlando Magic', 'Charlotte Hornets', 'Orlando Magic', datetime.date(2021, 5, 7), 233, 251, 1510, 141, 227, 249, 1530),
#  (118, 'Miami Heat vs. Minnesota Timberwolves', 'Miami Heat', 'Minnesota Timberwolves', datetime.date(2021, 5, 7), 283, 310, 2380, 118, 218, 234, 1430),
#  (148, 'Golden State Warriors vs. Oklahoma City Thunder', 'Golden State Warriors', 'Oklahoma City Thunder', datetime.date(2021, 5, 8), 434, 444, 5210, 148, 257, 280, 1660),
#  (27, 'Indiana Pacers vs. Washington Wizards', 'Indiana Pacers', 'Washington Wizards', datetime.date(2021, 5, 8), 228, 249, 1550, 27, 247, 278, 2050),
#  (8, 'Toronto Raptors vs. Memphis Grizzlies', 'Toronto Raptors', 'Memphis Grizzlies', datetime.date(2021, 5, 8), 292, 341, 2550, 8, 213, 229, 1360),
#  (102, 'Denver Nuggets vs. Brooklyn Nets', 'Denver Nuggets', 'Brooklyn Nets', datetime.date(2021, 5, 8), 226, 259, 1770, 102, 283, 312, 3400),
#  (50, 'Detroit Pistons vs. Chicago Bulls', 'Detroit Pistons', 'Chicago Bulls', datetime.date(2021, 5, 9), 258, 279, 1740, 50, 304, 322, 3140),
#  (60, 'Boston Celtics vs. Miami Heat', 'Boston Celtics', 'Miami Heat', datetime.date(2021, 5, 9), 308, 341, 3180, 60, 283, 310, 2380),
#  (15, 'Los Angeles Lakers vs. Phoenix Suns', 'Los Angeles Lakers', 'Phoenix Suns', datetime.date(2021, 5, 9), 418, 459, 5140, 15, 231, 249, 1640),
#  (150, 'Charlotte Hornets vs. New Orleans Pelicans', 'Charlotte Hornets', 'New Orleans Pelicans', datetime.date(2021, 5, 9), 233, 251, 1510, 150, 213, 229, 1350),
#  (107, 'Orlando Magic vs. Minnesota Timberwolves', 'Orlando Magic', 'Minnesota Timberwolves', datetime.date(2021, 5, 9), 227, 249, 1530, 107, 218, 234, 1430),
#  (133, 'Golden State Warriors vs. Utah Jazz', 'Golden State Warriors', 'Utah Jazz', datetime.date(2021, 5, 10), 434, 444, 5210, 133, 251, 273, 1710),
#  (21, 'Atlanta Hawks vs. Washington Wizards', 'Atlanta Hawks', 'Washington Wizards', datetime.date(2021, 5, 10), 236, 254, 1540, 21, 247, 278, 2050),
#  (139, 'Memphis Grizzlies vs. New Orleans Pelicans', 'Memphis Grizzlies', 'New Orleans Pelicans', datetime.date(2021, 5, 10), 213, 229, 1360, 139, 213, 229, 1350),
#  (158, 'San Antonio Spurs v Milwaukee Bucks Military Appreciation Night', 'San Antonio Spurs', 'Milwaukee Bucks', datetime.date(2021, 5, 10), 279, 298, 2050, 158, 259, 299, 1860),
#  (55, 'Memphis Grizzlies vs. Dallas Mavericks', 'Memphis Grizzlies', 'Dallas Mavericks', datetime.date(2021, 5, 11), 213, 229, 1360, 55, 296, 322, 2580),
#  (65, 'Los Angeles Lakers vs. New York Knicks', 'Los Angeles Lakers', 'New York Knicks', datetime.date(2021, 5, 11), 418, 459, 5140, 65, 428, 472, 5420),
#  (59, 'Boston Celtics vs. Miami Heat', 'Boston Celtics', 'Miami Heat', datetime.date(2021, 5, 11), 308, 341, 3180, 59, 283, 310, 2380),
#  (58, 'Toronto Raptors vs. Los Angeles Clippers', 'Toronto Raptors', 'LA Clippers', datetime.date(2021, 5, 11), 292, 341, 2550, 58, 297, 300, 2630),
#  (110, 'Milwaukee Bucks vs. Orlando Magic', 'Milwaukee Bucks', 'Orlando Magic', datetime.date(2021, 5, 11), 259, 299, 1860, 110, 227, 249, 1530),
#  (134, 'Golden State Warriors vs. Phoenix Suns', 'Golden State Warriors', 'Phoenix Suns', datetime.date(2021, 5, 11), 434, 444, 5210, 134, 231, 249, 1640),
#  (146, 'Indiana Pacers vs. Philadelphia 76ers', 'Indiana Pacers', 'Philadelphia 76ers', datetime.date(2021, 5, 11), 228, 249, 1550, 146, 284, 312, 2500),
#  (41, 'Detroit Pistons vs. Minnesota Timberwolves', 'Detroit Pistons', 'Minnesota Timberwolves', datetime.date(2021, 5, 11), 258, 279, 1740, 41, 218, 234, 1430),
#  (101, 'Charlotte Hornets vs. Denver Nuggets', 'Charlotte Hornets', 'Denver Nuggets', datetime.date(2021, 5, 11), 233, 251, 1510, 101, 226, 259, 1770),
#  (159, 'Brooklyn Nets vs. San Antonio Spurs', 'Brooklyn Nets', 'San Antonio Spurs', datetime.date(2021, 5, 12), 283, 312, 3400, 159, 279, 298, 2050),
#  (43, 'Los Angeles Lakers vs. Houston Rockets', 'Los Angeles Lakers', 'Houston Rockets', datetime.date(2021, 5, 12), 418, 459, 5140, 43, 344, 385, 2770),
#  (20, 'Atlanta Hawks vs. Washington Wizards', 'Atlanta Hawks', 'Washington Wizards', datetime.date(2021, 5, 12), 236, 254, 1540, 20, 247, 278, 2050),
#  (53, 'Dallas Mavericks vs. New Orleans Pelicans', 'Dallas Mavericks', 'New Orleans Pelicans', datetime.date(2021, 5, 12), 296, 322, 2580, 53, 213, 229, 1350),
#  (151, 'Phoenix Suns vs. Portland Trail Blazers', 'Phoenix Suns', 'Portland Trail Blazers', datetime.date(2021, 5, 13), 231, 249, 1640, 151, 258, 298, 1910),
#  (79, 'Charlotte Hornets vs. LA Clippers', 'Charlotte Hornets', 'LA Clippers', datetime.date(2021, 5, 13), 233, 251, 1510, 79, 297, 300, 2630),
#  (91, 'New York Knicks vs. San Antonio Spurs', 'New York Knicks', 'San Antonio Spurs', datetime.date(2021, 5, 13), 428, 472, 5420, 91, 279, 298, 2050),
#  (121, 'Atlanta Hawks vs. Orlando Magic', 'Atlanta Hawks', 'Orlando Magic', datetime.date(2021, 5, 13), 236, 254, 1540, 121, 227, 249, 1530),
#  (129, 'Memphis Grizzlies vs. Sacramento Kings', 'Memphis Grizzlies', 'Sacramento Kings', datetime.date(2021, 5, 13), 213, 229, 1360, 129, 275, 298, 1840),
#  (135, 'Indiana Pacers vs. Milwaukee Bucks', 'Indiana Pacers', 'Milwaukee Bucks', datetime.date(2021, 5, 13), 228, 249, 1550, 135, 259, 299, 1860),
#  (124, 'Miami Heat vs. Philadelphia 76ers', 'Miami Heat', 'Philadelphia 76ers', datetime.date(2021, 5, 13), 283, 310, 2380, 124, 284, 312, 2500),
#  (75, 'Washington Wizards vs. Cleveland Cavaliers', 'Washington Wizards', 'Cleveland Cavaliers', datetime.date(2021, 5, 14), 247, 278, 2050, 75, 256, 293, 1740),
#  (38, 'Dallas Mavericks vs. Toronto Raptors', 'Dallas Mavericks', 'Toronto Raptors', datetime.date(2021, 5, 14), 296, 322, 2580, 38, 292, 341, 2550),
#  (9, 'Houston Rockets vs. LA Clippers', 'Houston Rockets', 'LA Clippers', datetime.date(2021, 5, 14), 344, 385, 2770, 9, 297, 300, 2630),
#  (126, 'Memphis Grizzlies vs. Sacramento Kings', 'Memphis Grizzlies', 'Sacramento Kings', datetime.date(2021, 5, 14), 213, 229, 1360, 126, 275, 298, 1840),
#  (149, 'Golden State Warriors vs. New Orleans Pelicans', 'Golden State Warriors', 'New Orleans Pelicans', datetime.date(2021, 5, 14), 434, 444, 5210, 149, 213, 229, 1350),
#  (94, 'Detroit Pistons vs. Denver Nuggets', 'Detroit Pistons', 'Denver Nuggets', datetime.date(2021, 5, 14), 258, 279, 1740, 94, 226, 259, 1770),
#  (82, 'Brooklyn Nets vs. Chicago Bulls', 'Brooklyn Nets', 'Chicago Bulls', datetime.date(2021, 5, 15), 283, 312, 3400, 82, 304, 322, 3140),
#  (108, 'Milwaukee Bucks vs. Miami Heat', 'Milwaukee Bucks', 'Miami Heat', datetime.date(2021, 5, 15), 259, 299, 1860, 108, 283, 310, 2380),
#  (18, 'Indiana Pacers vs. Los Angeles Lakers', 'Indiana Pacers', 'Los Angeles Lakers', datetime.date(2021, 5, 15), 228, 249, 1550, 18, 418, 459, 5140),
#  (90, 'New York Knicks vs. Charlotte Hornets', 'New York Knicks', 'Charlotte Hornets', datetime.date(2021, 5, 15), 428, 472, 5420, 90, 233, 251, 1510),
#  (157, 'San Antonio Spurs v Phoenix Suns Tim Duncan Hall of Fame Night', 'San Antonio Spurs', 'Phoenix Suns', datetime.date(2021, 5, 15), 279, 298, 2050, 157, 231, 249, 1640),
#  (84, 'Brooklyn Nets vs. Cleveland Cavaliers', 'Brooklyn Nets', 'Cleveland Cavaliers', datetime.date(2021, 5, 16), 283, 312, 3400, 84, 256, 293, 1740),
#  (37, 'Detroit Pistons vs. Miami Heat', 'Detroit Pistons', 'Miami Heat', datetime.date(2021, 5, 16), 258, 279, 1740, 37, 283, 310, 2380),
#  (85, 'New York Knicks vs. Boston Celtics', 'New York Knicks', 'Boston Celtics', datetime.date(2021, 5, 16), 428, 472, 5420, 85, 308, 341, 3180),
#  (48, 'Atlanta Hawks vs. Houston Rockets', 'Atlanta Hawks', 'Houston Rockets', datetime.date(2021, 5, 16), 236, 254, 1540, 48, 344, 385, 2770),
#  (35, 'Washington Wizards vs. Charlotte Hornets', 'Washington Wizards', 'Charlotte Hornets', datetime.date(2021, 5, 16), 247, 278, 2050, 35, 233, 251, 1510),
#  (161, 'San Antonio Spurs v Phoenix Suns Fiesta Court Beach Towels Giveaway', 'San Antonio Spurs', 'Phoenix Suns', datetime.date(2021, 5, 16), 279, 298, 2050, 161, 231, 249, 1640),
#  (10, 'Toronto Raptors vs. Indiana Pacers', 'Toronto Raptors', 'Indiana Pacers', datetime.date(2021, 5, 16), 292, 341, 2550, 10, 228, 249, 1550),
#  (136, 'Golden State Warriors vs. Memphis Grizzlies', 'Golden State Warriors', 'Memphis Grizzlies', datetime.date(2021, 5, 16), 434, 444, 5210, 136, 213, 229, 1360)]

# %% [markdown]
# Reccomendation: This query should be used to help price tickets for teams based on the teams they are playing and their market size. There are some teams that regardless of their team success, the organizations ability to generate revenue and sell tickets is going to be determined by the market size. For example, a small market team like the Memphis Grizzlies who had regular season and playoff success in the Mike Conley/Marc Gasol era could not generate as high of revenue and ticket sales as a team like the New York Knicks who were not as succesful because of the market each team played in. By looking at the revenue numbers, we can get an idea of how to price tickets based on that.
